# %%
import os
from experiments.data_loaders.standard_loader import MyDataLoader
# from infers.simple_mnist_infer import SimpleMnistInfer
from perception.models.dense_unet import  SegmentionModel
from perception.trainers.segmention_trainer import SegmentionTrainer
from configs.utils.config_utils import process_config
import numpy as np
import cv2
import matplotlib.pyplot as plt

#print(help(plt.imread))
# Out:
# Using TensorFlow backend.

# %%
def main_train():
    """
    训练模型

    :return:
    """
    print('[INFO] Reading Configs...')

    config = None

    try:
        config = process_config('./configs/segmention_config.json')  
        config.prob_path = '.\\experiments\\VesselNet\\dataset\\DRIVE\\train\\probmap2\\'
        config.prob_val_path = '.\\experiments\\VesselNet\\dataset\\DRIVE\\validate\\probmap2\\'        
        
        #config.train_img_path = ".\\experiments\\VesselNet\\dataset\\DRIVE\\train\\20_images\\"
        #config.train_groundtruth_path = ".\\experiments\\VesselNet\\dataset\\DRIVE\\train\\final_gt\\"
        #config.seg_num = 4
        #config.num_seg_class = 4
        #config.val_img_path = ".\\experiments\\VesselNet\\dataset\\DRIVE\\validate\\dark\\"
        #config.val_groundtruth_path = ".\\experiments\\VesselNet\\dataset\\DRIVE\\validate\\final_gt\\"
         
     #   config.train_img_path = ".\\experiments\\VesselNet\\dataset\\DRIVE\\train\\bright\\"
     #   config.train_groundtruth_path = ".\\experiments\\VesselNet\\dataset\\DRIVE\\train\\bright_gt\\"
     #   config.val_img_path = ".\\experiments\\VesselNet\\dataset\\DRIVE\\validate\\bright\\"
     #   config.val_groundtruth_path = ".\\experiments\\VesselNet\\dataset\\DRIVE\\validate\\bright_gt\\"
         
        
        #config.train_img_path = ".\\experiments\\VesselNet\\dataset\\HRF\\train\\images\\"
        #config.train_groundtruth_path = ".\\experiments\\VesselNet\\dataset\\HRF\\train\\gt\\"
        #config.val_img_path = ".\\experiments\\VesselNet\\dataset\\HRF\\validate\\images\\"
        #config.val_groundtruth_path = ".\\experiments\\VesselNet\\dataset\\HRF\\validate\\gt\\"
        #config.height = 1168
        #config.width = 1727
        
        #config.val_img_path = ".\\experiments\\VesselNet\\dataset\\DRIVE\\validate\\FOV\\"
        #config.val_groundtruth_path = ".\\experiments\\VesselNet\\dataset\\DRIVE\\validate\\FOV_gt\\"


        
        config.patch_height = 128
        config.patch_width = 128
        config.stride_width = 32
        config.stride_height = 32
        config.train_img_path = ".\\experiments\\VesselNet\\dataset\\DRIVE\\train\\origin\\"
        config.train_groundtruth_path = ".\\experiments\\VesselNet\\dataset\\DRIVE\\train\\gt\\"
        config.val_img_path = ".\\experiments\\VesselNet\\dataset\\DRIVE\\validate\\origin\\"
        config.val_groundtruth_path = ".\\experiments\\VesselNet\\dataset\\DRIVE\\validate\\groundtruth\\"
        #config.height = 540
        #config.width = 540
        
        #config = process_config('./configs/segmention_config_CHASEDB1.json')
       # config = process_config('./configs/segmention_config.json')        
       # config.train_img_path = ".\\experiments\\VesselNet\\dataset\\CHASEDB1\\train\\"
        #config.train_groundtruth_path =".\\experiments\\VesselNet\\dataset\\train\\"
        
        #config.val_img_path = ".\\experiments\\VesselNet\\dataset\\CHASEDB1\\validate\\"
        #config.val_groundtruth_path = ".\\experiments\\VesselNet\\dataset\\validate\\groundtruth\\"
        
        #config.val_datatype = 'jpg'
        #config.val_gt_datatype = 'png'
        #config.height  = 960
        #config.width = 999
        
        
       # config = process_config('./configs/segmention_config_STARE.json')
       #config = process_config('./configs/segmention_config.json')        
       # config.train_img_path = ".\\experiments\\VesselNet\\dataset\\STARE\\img_bmp\\"
       # config.train_groundtruth_path =".\\experiments\\VesselNet\\dataset\\STARE\\gt_bmp\\"
      #  config.val_img_path = ".\\experiments\\VesselNet\\dataset\\STARE\\img_bmp\\"
      #  config.val_groundtruth_path = ".\\experiments\\VesselNet\\dataset\\STARE\\gt_bmp\\"     
      #  config.height = 
      #  config.width = 700
        config.epochs = 15
        
       # config.test_img_path =".\\experiments\\VesselNet\\test\\probmap\\"
        config.epoch = 30
        config.G = 0.8
        config.R = 0.2
        config.B = 0.0
        config.color_space = 'RGB'
        config.batch_size = 8
        #config.color_space = 'HSV'
        config.multi_proportion = 1
        print(config)
    except Exception as e:
        print('[Exception] Config Error, %s' % e)
        exit(0)
    # np.random.seed(47)  # 固定随机数

    print('[INFO] Preparing Data...')
    #dataloader = MyDataLoader(config=config,dataset='CHASEDB1')
    #dataloader = MyDataLoader(config=config,dataset='HRF')
    dataloader = MyDataLoader(config=config,dataset='DRIVE')
   #dataloader = MyDataLoader(config=config,dataset='DRIVE_MULTICLASS')
    #dataloader = MyDataLoader(config=config,dataset='CHASEDB1')
    dataloader.prepare_dataset()
    mode = 'DRIVE'
    #target_path = './metric/STARE/'
    if mode == 'STARE':
        config = process_config('./configs/segmention_config_STARE.json')
        config = process_config('./configs/segmention_config.json')        
        config.train_img_path = ".\\experiments\\VesselNet\\dataset\\STARE\\img_bmp\\"
        config.train_groundtruth_path =".\\experiments\\VesselNet\\dataset\\STARE\\gt_bmp\\"
        config.val_img_path = ".\\experiments\\VesselNet\\dataset\\STARE\\img_bmp\\"
        config.val_groundtruth_path = ".\\experiments\\VesselNet\\dataset\\STARE\\gt_bmp\\"     
        config.height = 605
        config.width = 700
        config.epochs = 6   
        config.color_space = 'LAB'
        #config.color_space = 'HSV'
        config.multi_proportion = False      
        total_imgs,total_gt=dataloader.get_train_data()
        #print(train_imgs.shape) 
        
        for iter_ in range(20):
            if not os.path.exists(target_path+'test'):
                os.mkdir(target_path+'test')
            if not os.path.exists(target_path+'mask'):
                os.mkdir(target_path+'mask')
                
            val_imgs, val_gt = total_imgs[iter_,:,:,:] , total_gt[iter_,:,:,:]
            cv2.imwrite(target_path+'test/'+str(iter_)+'.bmp',val_imgs)
            cv2.imwrite(target_path+'tmask/'+str(iter_)+'.bmp',val_gt)
            val_imgs = np.expand_dims(val_imgs,0)
            val_gt = np.expand_dims(val_gt,0)
            if iter_ == 0:
                
           # val_imgs, val_gt = total_imgs[iter_] , total_gt[iter_]
                train_imgs , train_gt = total_imgs[1:,:,:,:], total_gt[1:,:,:,:]
                #train_imgs, train_gt = np.expand_dims(train_imgs,0),np.expand_dims(train_gt,0)
            elif iter_ == 19:
                train_imgs,train_gt = total_imgs[:iter_,:,:,:], total_gt[:iter_,:,:,:] 
            else:
                train_imgs,train_gt = np.concatenate([total_imgs[:iter_,:,:,:],total_imgs[iter_+1:,:,:,:]],axis=0),np.concatenate([total_gt[:iter_,:,:,:],total_gt[iter_+1:,:,:,:]],axis=0)
            print(iter_)
            print(train_imgs.shape)
            print(total_imgs.shape)
            print('[INFO] Building Model...')
            model = SegmentionModel(config=config)
#
            print('[INFO] Training...iter:{}'.format(iter_))
            trainer = SegmentionTrainer(
            model=model.model,
            data=[train_imgs,train_gt,val_imgs,val_gt],
            config=config,
            iter_=iter_)
            trainer.train()
            print('[INFO] Finishing...iter:{}'.format(iter_))
    else:
        iter_ = 'DRIVE_Binary'
        #total_imgs, total_gt = dataloader.get_train_data()
        #train_imgs = np.array(list(total_imgs[:18,:,:,:]) + list(total_imgs[20:20+18,:,:,:]))
        #train_gt = np.array(list(total_gt[:18,:,:,:]) + list(total_gt[20:20+18,:,:,:]))
        #val_imgs = np.array(list(total_imgs[18:20,:,:,:]) + list(total_imgs[20+18:,:,:,:]))
        #val_gt = np.array(list(total_gt[18:20,:,:,:]) + list(total_gt[20+18:,:,:,:]))        
        #val_imgs = train_imgs[16:20,:,:,:]+train_imgs[20+16:,:,:,:]
        #val_gt = train_gt[16:20,:,:,:]+train_gt[20+16:,:,:,:]
        train_imgs, train_gt = dataloader.get_train_data()

        val_imgs,val_gt= dataloader.get_val_data()
        #prob_map,prob_val_map = dataloader.get_prob_data()
        print(train_imgs.shape)
        #print(val_imgs.shape)
       # print(prob_map.shape)
       # print(prob_val_map.shape)
        print('[INFO] Building Model...')
        model = SegmentionModel(config=config)
        
        print('[INFO] Training...')
        trainer = SegmentionTrainer(
        model=model.model,
        data=[train_imgs,train_gt,val_imgs,val_gt],
        config=config,
        iter_=iter_)
        trainer.train()
        print('[INFO] Finishing...')

# %%
if __name__ == '__main__':
    print('Staring Train')
    main_train()
    # test_main()
# Out:
# Staring Train
# [INFO] Reading Configs...
# B: 0.0
# G: 0.8
# R: 0.2
# batch_size: 8
# checkpoint: ./experiments\VesselNet\checkpoint/
# color_space: RGB
# epoch: 30
# epochs: 15
# exp_name: VesselNet
# hdf5_path: ./experiments\VesselNet\hdf5/
# height: 584
# multi_proportion: 1
# patch_height: 128
# patch_width: 128
# prob_path: .\experiments\VesselNet\dataset\DRIVE\train\probmap2\
# prob_val_path: .\experiments\VesselNet\dataset\DRIVE\validate\probmap2\
# seg_num: 1
# stride_height: 32
# stride_width: 32
# subsample: 500
# test_datatype: tif
# test_gt_datatype: tif
# test_gt_path: ./experiments\VesselNet\test/groundtruth/
# test_img_path: ./experiments\VesselNet\test/origin/
# test_result_path: ./experiments\VesselNet\test/result/
# total_train: 40
# total_val: 20
# train_datatype: tif
# train_groundtruth_path: .\experiments\VesselNet\dataset\DRIVE\train\gt\
# train_gt_datatype: tif
# train_img_path: .\experiments\VesselNet\dataset\DRIVE\train\origin\
# val_datatype: tif
# val_groundtruth_path: .\experiments\VesselNet\dataset\DRIVE\validate\groundtruth\
# val_gt_datatype: tif
# val_img_path: .\experiments\VesselNet\dataset\DRIVE\validate\origin\
# width: 565
#
# [INFO] Preparing Data...
# Writing DRIVE....
# .\experiments\VesselNet\dataset\DRIVE\train\origin\
# .\experiments\VesselNet\dataset\DRIVE\train\gt\
# (40, 584, 565, 1)
# Color Space: RGB
# ratio:0.8 R_ratio:0.2 B_ratio:0.0
# (40, 584, 565, 1)
# Color Space: RGB
# ratio:0.8 R_ratio:0.2 B_ratio:0.0
# (40, 584, 565, 1)
# Color Space: RGB
# ratio:0.8 R_ratio:0.2 B_ratio:0.0
# (40, 584, 565, 1)
# Color Space: RGB
# ratio:0.8 R_ratio:0.2 B_ratio:0.0
# (40, 584, 565, 1)
# Color Space: RGB
# ratio:0.8 R_ratio:0.2 B_ratio:0.0
# (40, 584, 565, 1)
# Color Space: RGB
# ratio:0.8 R_ratio:0.2 B_ratio:0.0
# (40, 584, 565, 1)
# Color Space: RGB
# ratio:0.8 R_ratio:0.2 B_ratio:0.0
# (40, 584, 565, 1)
# Color Space: RGB
# ratio:0.8 R_ratio:0.2 B_ratio:0.0
# (40, 584, 565, 1)
# Color Space: RGB
# ratio:0.8 R_ratio:0.2 B_ratio:0.0
# (40, 584, 565, 1)
# Color Space: RGB
# ratio:0.8 R_ratio:0.2 B_ratio:0.0
# (40, 584, 565, 1)
# Color Space: RGB
# ratio:0.8 R_ratio:0.2 B_ratio:0.0
# (40, 584, 565, 1)
# Color Space: RGB
# ratio:0.8 R_ratio:0.2 B_ratio:0.0
# (40, 584, 565, 1)
# Color Space: RGB
# ratio:0.8 R_ratio:0.2 B_ratio:0.0
# (40, 584, 565, 1)
# Color Space: RGB
# ratio:0.8 R_ratio:0.2 B_ratio:0.0
# (40, 584, 565, 1)
# Color Space: RGB
# ratio:0.8 R_ratio:0.2 B_ratio:0.0
# (40, 584, 565, 1)
# Color Space: RGB
# ratio:0.8 R_ratio:0.2 B_ratio:0.0
# (40, 584, 565, 1)
# Color Space: RGB
# ratio:0.8 R_ratio:0.2 B_ratio:0.0
# (40, 584, 565, 1)
# Color Space: RGB
# ratio:0.8 R_ratio:0.2 B_ratio:0.0
# (40, 584, 565, 1)
# Color Space: RGB
# ratio:0.8 R_ratio:0.2 B_ratio:0.0
# (40, 584, 565, 1)
# Color Space: RGB
# ratio:0.8 R_ratio:0.2 B_ratio:0.0
# (40, 584, 565, 1)
# Color Space: RGB
# ratio:0.8 R_ratio:0.2 B_ratio:0.0
# (40, 584, 565, 1)
# Color Space: RGB
# ratio:0.8 R_ratio:0.2 B_ratio:0.0
# (40, 584, 565, 1)
# Color Space: RGB
# ratio:0.8 R_ratio:0.2 B_ratio:0.0
# (40, 584, 565, 1)
# Color Space: RGB
# ratio:0.8 R_ratio:0.2 B_ratio:0.0
# (40, 584, 565, 1)
# Color Space: RGB
# ratio:0.8 R_ratio:0.2 B_ratio:0.0
# (40, 584, 565, 1)
# Color Space: RGB
# ratio:0.8 R_ratio:0.2 B_ratio:0.0
# (40, 584, 565, 1)
# Color Space: RGB
# ratio:0.8 R_ratio:0.2 B_ratio:0.0
# (40, 584, 565, 1)
# Color Space: RGB
# ratio:0.8 R_ratio:0.2 B_ratio:0.0
# (40, 584, 565, 1)
# Color Space: RGB
# ratio:0.8 R_ratio:0.2 B_ratio:0.0
# (40, 584, 565, 1)
# Color Space: RGB
# ratio:0.8 R_ratio:0.2 B_ratio:0.0
# (40, 584, 565, 1)
# Color Space: RGB
# ratio:0.8 R_ratio:0.2 B_ratio:0.0
# (40, 584, 565, 1)
# Color Space: RGB
# ratio:0.8 R_ratio:0.2 B_ratio:0.0
# (40, 584, 565, 1)
# Color Space: RGB
# ratio:0.8 R_ratio:0.2 B_ratio:0.0
# (40, 584, 565, 1)
# Color Space: RGB
# ratio:0.8 R_ratio:0.2 B_ratio:0.0
# (40, 584, 565, 1)
# Color Space: RGB
# ratio:0.8 R_ratio:0.2 B_ratio:0.0
# (40, 584, 565, 1)
# Color Space: RGB
# ratio:0.8 R_ratio:0.2 B_ratio:0.0
# (40, 584, 565, 1)
# Color Space: RGB
# ratio:0.8 R_ratio:0.2 B_ratio:0.0
# (40, 584, 565, 1)
# Color Space: RGB
# ratio:0.8 R_ratio:0.2 B_ratio:0.0
# (40, 584, 565, 1)
# Color Space: RGB
# ratio:0.8 R_ratio:0.2 B_ratio:0.0
# (40, 584, 565, 1)
# Color Space: RGB
# ratio:0.8 R_ratio:0.2 B_ratio:0.0
# [INFO] Reading...
# .\experiments\VesselNet\dataset\DRIVE\validate\origin\
# .\experiments\VesselNet\dataset\DRIVE\validate\groundtruth\
# (20, 584, 565, 1)
# Color Space: RGB
# ratio:0.8 R_ratio:0.2 B_ratio:0.0
# (20, 584, 565, 1)
# Color Space: RGB
# ratio:0.8 R_ratio:0.2 B_ratio:0.0
# (20, 584, 565, 1)
# Color Space: RGB
# ratio:0.8 R_ratio:0.2 B_ratio:0.0
# (20, 584, 565, 1)
# Color Space: RGB
# ratio:0.8 R_ratio:0.2 B_ratio:0.0
# (20, 584, 565, 1)
# Color Space: RGB
# ratio:0.8 R_ratio:0.2 B_ratio:0.0
# (20, 584, 565, 1)
# Color Space: RGB
# ratio:0.8 R_ratio:0.2 B_ratio:0.0
# (20, 584, 565, 1)
# Color Space: RGB
# ratio:0.8 R_ratio:0.2 B_ratio:0.0
# (20, 584, 565, 1)
# Color Space: RGB
# ratio:0.8 R_ratio:0.2 B_ratio:0.0
# (20, 584, 565, 1)
# Color Space: RGB
# ratio:0.8 R_ratio:0.2 B_ratio:0.0
# (20, 584, 565, 1)
# Color Space: RGB
# ratio:0.8 R_ratio:0.2 B_ratio:0.0
# (20, 584, 565, 1)
# Color Space: RGB
# ratio:0.8 R_ratio:0.2 B_ratio:0.0
# (20, 584, 565, 1)
# Color Space: RGB
# ratio:0.8 R_ratio:0.2 B_ratio:0.0
# (20, 584, 565, 1)
# Color Space: RGB
# ratio:0.8 R_ratio:0.2 B_ratio:0.0
# (20, 584, 565, 1)
# Color Space: RGB
# ratio:0.8 R_ratio:0.2 B_ratio:0.0
# (20, 584, 565, 1)
# Color Space: RGB
# ratio:0.8 R_ratio:0.2 B_ratio:0.0
# (20, 584, 565, 1)
# Color Space: RGB
# ratio:0.8 R_ratio:0.2 B_ratio:0.0
# (20, 584, 565, 1)
# Color Space: RGB
# ratio:0.8 R_ratio:0.2 B_ratio:0.0
# (20, 584, 565, 1)
# Color Space: RGB
# ratio:0.8 R_ratio:0.2 B_ratio:0.0
# (20, 584, 565, 1)
# Color Space: RGB
# ratio:0.8 R_ratio:0.2 B_ratio:0.0
# (20, 584, 565, 1)
# Color Space: RGB
# ratio:0.8 R_ratio:0.2 B_ratio:0.0
# [INFO] Reading...
# [INFO] Saving Training Data
# [INFO] Saving Validation Data
# (40, 584, 565, 1)
# [INFO] Building Model...
# Model Input Channel : 1
# [INFO] Saving model...
# [INFO] Model saved
# [INFO] Training...
# Epoch 1/15
# 100/100 [==============================] - ETA: 12:42 - loss: 0.7289 - binary_accuracy: 0.5517 - dice_coef: 0.28 - ETA: 6:25 - loss: 0.6944 - binary_accuracy: 0.6130 - dice_coef: 0.3657 - ETA: 4:18 - loss: 0.6837 - binary_accuracy: 0.6128 - dice_coef: 0.374 - ETA: 3:15 - loss: 0.6683 - binary_accuracy: 0.6272 - dice_coef: 0.391 - ETA: 2:36 - loss: 0.6470 - binary_accuracy: 0.6544 - dice_coef: 0.419 - ETA: 2:11 - loss: 0.6304 - binary_accuracy: 0.6775 - dice_coef: 0.445 - ETA: 1:53 - loss: 0.6147 - binary_accuracy: 0.6946 - dice_coef: 0.466 - ETA: 1:39 - loss: 0.6047 - binary_accuracy: 0.7077 - dice_coef: 0.479 - ETA: 1:28 - loss: 0.5927 - binary_accuracy: 0.7177 - dice_coef: 0.494 - ETA: 1:20 - loss: 0.5868 - binary_accuracy: 0.7262 - dice_coef: 0.501 - ETA: 1:13 - loss: 0.5729 - binary_accuracy: 0.7378 - dice_coef: 0.520 - ETA: 1:07 - loss: 0.5615 - binary_accuracy: 0.7470 - dice_coef: 0.535 - ETA: 1:02 - loss: 0.5630 - binary_accuracy: 0.7548 - dice_coef: 0.537 - ETA: 57s - loss: 0.5523 - binary_accuracy: 0.7619 - dice_coef: 0.549 - ETA: 54s - loss: 0.5511 - binary_accuracy: 0.7668 - dice_coef: 0.55 - ETA: 50s - loss: 0.5480 - binary_accuracy: 0.7715 - dice_coef: 0.55 - ETA: 48s - loss: 0.5414 - binary_accuracy: 0.7734 - dice_coef: 0.56 - ETA: 45s - loss: 0.5360 - binary_accuracy: 0.7768 - dice_coef: 0.56 - ETA: 43s - loss: 0.5317 - binary_accuracy: 0.7798 - dice_coef: 0.57 - ETA: 40s - loss: 0.5269 - binary_accuracy: 0.7845 - dice_coef: 0.57 - ETA: 38s - loss: 0.5229 - binary_accuracy: 0.7882 - dice_coef: 0.58 - ETA: 37s - loss: 0.5176 - binary_accuracy: 0.7908 - dice_coef: 0.58 - ETA: 35s - loss: 0.5114 - binary_accuracy: 0.7947 - dice_coef: 0.59 - ETA: 34s - loss: 0.5084 - binary_accuracy: 0.7989 - dice_coef: 0.59 - ETA: 32s - loss: 0.5060 - binary_accuracy: 0.8021 - dice_coef: 0.60 - ETA: 31s - loss: 0.5037 - binary_accuracy: 0.8043 - dice_coef: 0.60 - ETA: 30s - loss: 0.5019 - binary_accuracy: 0.8065 - dice_coef: 0.60 - ETA: 28s - loss: 0.4994 - binary_accuracy: 0.8092 - dice_coef: 0.61 - ETA: 27s - loss: 0.4971 - binary_accuracy: 0.8098 - dice_coef: 0.61 - ETA: 26s - loss: 0.4979 - binary_accuracy: 0.8124 - dice_coef: 0.61 - ETA: 25s - loss: 0.4952 - binary_accuracy: 0.8152 - dice_coef: 0.61 - ETA: 25s - loss: 0.4920 - binary_accuracy: 0.8175 - dice_coef: 0.62 - ETA: 24s - loss: 0.4893 - binary_accuracy: 0.8192 - dice_coef: 0.62 - ETA: 23s - loss: 0.4861 - binary_accuracy: 0.8212 - dice_coef: 0.62 - ETA: 22s - loss: 0.4843 - binary_accuracy: 0.8227 - dice_coef: 0.62 - ETA: 21s - loss: 0.4828 - binary_accuracy: 0.8249 - dice_coef: 0.63 - ETA: 21s - loss: 0.4812 - binary_accuracy: 0.8267 - dice_coef: 0.63 - ETA: 20s - loss: 0.4796 - binary_accuracy: 0.8281 - dice_coef: 0.63 - ETA: 19s - loss: 0.4763 - binary_accuracy: 0.8302 - dice_coef: 0.63 - ETA: 19s - loss: 0.4778 - binary_accuracy: 0.8314 - dice_coef: 0.63 - ETA: 18s - loss: 0.4747 - binary_accuracy: 0.8326 - dice_coef: 0.64 - ETA: 18s - loss: 0.4721 - binary_accuracy: 0.8337 - dice_coef: 0.64 - ETA: 17s - loss: 0.4722 - binary_accuracy: 0.8346 - dice_coef: 0.64 - ETA: 17s - loss: 0.4691 - binary_accuracy: 0.8354 - dice_coef: 0.64 - ETA: 16s - loss: 0.4671 - binary_accuracy: 0.8363 - dice_coef: 0.64 - ETA: 16s - loss: 0.4646 - binary_accuracy: 0.8375 - dice_coef: 0.64 - ETA: 15s - loss: 0.4620 - binary_accuracy: 0.8385 - dice_coef: 0.65 - ETA: 15s - loss: 0.4592 - binary_accuracy: 0.8393 - dice_coef: 0.65 - ETA: 14s - loss: 0.4577 - binary_accuracy: 0.8404 - dice_coef: 0.65 - ETA: 14s - loss: 0.4561 - binary_accuracy: 0.8412 - dice_coef: 0.65 - ETA: 13s - loss: 0.4538 - binary_accuracy: 0.8420 - dice_coef: 0.65 - ETA: 13s - loss: 0.4528 - binary_accuracy: 0.8427 - dice_coef: 0.65 - ETA: 12s - loss: 0.4503 - binary_accuracy: 0.8434 - dice_coef: 0.66 - ETA: 12s - loss: 0.4471 - binary_accuracy: 0.8447 - dice_coef: 0.66 - ETA: 12s - loss: 0.4462 - binary_accuracy: 0.8456 - dice_coef: 0.66 - ETA: 11s - loss: 0.4436 - binary_accuracy: 0.8465 - dice_coef: 0.66 - ETA: 11s  ...
#
# Epoch 00001: val_loss improved from inf to 0.30382, saving model to ./keras_DRIVE_Binary.model
# Epoch 2/15
# 100/100 [==============================] - ETA: 14s - loss: 0.2393 - binary_accuracy: 0.9201 - dice_coef: 0.82 - ETA: 13s - loss: 0.2815 - binary_accuracy: 0.9126 - dice_coef: 0.78 - ETA: 13s - loss: 0.2807 - binary_accuracy: 0.9078 - dice_coef: 0.77 - ETA: 13s - loss: 0.2776 - binary_accuracy: 0.9007 - dice_coef: 0.77 - ETA: 12s - loss: 0.2782 - binary_accuracy: 0.9042 - dice_coef: 0.77 - ETA: 12s - loss: 0.2781 - binary_accuracy: 0.9023 - dice_coef: 0.77 - ETA: 12s - loss: 0.2747 - binary_accuracy: 0.9007 - dice_coef: 0.78 - ETA: 12s - loss: 0.2775 - binary_accuracy: 0.9044 - dice_coef: 0.78 - ETA: 12s - loss: 0.2767 - binary_accuracy: 0.9050 - dice_coef: 0.78 - ETA: 12s - loss: 0.2754 - binary_accuracy: 0.9064 - dice_coef: 0.78 - ETA: 11s - loss: 0.2723 - binary_accuracy: 0.9075 - dice_coef: 0.78 - ETA: 11s - loss: 0.2721 - binary_accuracy: 0.9093 - dice_coef: 0.78 - ETA: 11s - loss: 0.2758 - binary_accuracy: 0.9112 - dice_coef: 0.78 - ETA: 11s - loss: 0.2760 - binary_accuracy: 0.9111 - dice_coef: 0.78 - ETA: 11s - loss: 0.2757 - binary_accuracy: 0.9125 - dice_coef: 0.78 - ETA: 11s - loss: 0.2737 - binary_accuracy: 0.9122 - dice_coef: 0.78 - ETA: 11s - loss: 0.2730 - binary_accuracy: 0.9133 - dice_coef: 0.78 - ETA: 10s - loss: 0.2731 - binary_accuracy: 0.9138 - dice_coef: 0.78 - ETA: 10s - loss: 0.2723 - binary_accuracy: 0.9135 - dice_coef: 0.78 - ETA: 10s - loss: 0.2723 - binary_accuracy: 0.9138 - dice_coef: 0.79 - ETA: 10s - loss: 0.2697 - binary_accuracy: 0.9132 - dice_coef: 0.79 - ETA: 10s - loss: 0.2685 - binary_accuracy: 0.9129 - dice_coef: 0.79 - ETA: 10s - loss: 0.2673 - binary_accuracy: 0.9130 - dice_coef: 0.79 - ETA: 10s - loss: 0.2643 - binary_accuracy: 0.9139 - dice_coef: 0.79 - ETA: 10s - loss: 0.2663 - binary_accuracy: 0.9135 - dice_coef: 0.79 - ETA: 9s - loss: 0.2647 - binary_accuracy: 0.9128 - dice_coef: 0.7944 - ETA: 9s - loss: 0.2658 - binary_accuracy: 0.9126 - dice_coef: 0.793 - ETA: 9s - loss: 0.2655 - binary_accuracy: 0.9126 - dice_coef: 0.792 - ETA: 9s - loss: 0.2648 - binary_accuracy: 0.9124 - dice_coef: 0.793 - ETA: 9s - loss: 0.2639 - binary_accuracy: 0.9134 - dice_coef: 0.794 - ETA: 9s - loss: 0.2642 - binary_accuracy: 0.9132 - dice_coef: 0.793 - ETA: 9s - loss: 0.2634 - binary_accuracy: 0.9135 - dice_coef: 0.794 - ETA: 8s - loss: 0.2636 - binary_accuracy: 0.9134 - dice_coef: 0.794 - ETA: 8s - loss: 0.2632 - binary_accuracy: 0.9136 - dice_coef: 0.794 - ETA: 8s - loss: 0.2632 - binary_accuracy: 0.9135 - dice_coef: 0.794 - ETA: 8s - loss: 0.2622 - binary_accuracy: 0.9139 - dice_coef: 0.795 - ETA: 8s - loss: 0.2624 - binary_accuracy: 0.9137 - dice_coef: 0.795 - ETA: 8s - loss: 0.2611 - binary_accuracy: 0.9136 - dice_coef: 0.796 - ETA: 8s - loss: 0.2610 - binary_accuracy: 0.9139 - dice_coef: 0.796 - ETA: 7s - loss: 0.2603 - binary_accuracy: 0.9138 - dice_coef: 0.796 - ETA: 7s - loss: 0.2595 - binary_accuracy: 0.9140 - dice_coef: 0.797 - ETA: 7s - loss: 0.2604 - binary_accuracy: 0.9141 - dice_coef: 0.797 - ETA: 7s - loss: 0.2603 - binary_accuracy: 0.9142 - dice_coef: 0.797 - ETA: 7s - loss: 0.2591 - binary_accuracy: 0.9142 - dice_coef: 0.798 - ETA: 7s - loss: 0.2592 - binary_accuracy: 0.9140 - dice_coef: 0.797 - ETA: 7s - loss: 0.2591 - binary_accuracy: 0.9138 - dice_coef: 0.797 - ETA: 7s - loss: 0.2584 - binary_accuracy: 0.9141 - dice_coef: 0.798 - ETA: 6s - loss: 0.2575 - binary_accuracy: 0.9142 - dice_coef: 0.798 - ETA: 6s - loss: 0.2569 - binary_accuracy: 0.9148 - dice_coef: 0.799 - ETA: 6s - loss: 0.2563 - binary_accuracy: 0.9150 - dice_coef: 0.799 - ETA: 6s - loss: 0.2559 - binary_accuracy: 0.9149 - dice_coef: 0.799 - ETA: 6s - loss: 0.2554 - binary_accuracy: 0.9149 - dice_coef: 0.799 - ETA: 6s - loss: 0.2545 - binary_accuracy: 0.9151 - dice_coef: 0.800 - ETA: 6s - loss: 0.2545 - binary_accuracy: 0.9153 - dice_coef: 0.800 - ETA: 5s - loss: 0.2545 - binary_accuracy: 0.9156 - dice_coef: 0.800 - ETA: 5s - loss: 0.2541 - binary_accuracy: 0.9156 - dice_coef: 0.800 - ETA: 5s - loss: 0.2538 - binary_accu ...
#
# Epoch 00002: val_loss improved from 0.30382 to 0.23201, saving model to ./keras_DRIVE_Binary.model
# Epoch 3/15
# 100/100 [==============================] - ETA: 13s - loss: 0.1908 - binary_accuracy: 0.9388 - dice_coef: 0.84 - ETA: 12s - loss: 0.1951 - binary_accuracy: 0.9256 - dice_coef: 0.83 - ETA: 13s - loss: 0.1959 - binary_accuracy: 0.9159 - dice_coef: 0.83 - ETA: 13s - loss: 0.2156 - binary_accuracy: 0.9191 - dice_coef: 0.81 - ETA: 13s - loss: 0.2265 - binary_accuracy: 0.9232 - dice_coef: 0.81 - ETA: 12s - loss: 0.2247 - binary_accuracy: 0.9235 - dice_coef: 0.81 - ETA: 12s - loss: 0.2307 - binary_accuracy: 0.9222 - dice_coef: 0.80 - ETA: 12s - loss: 0.2287 - binary_accuracy: 0.9245 - dice_coef: 0.80 - ETA: 12s - loss: 0.2286 - binary_accuracy: 0.9239 - dice_coef: 0.80 - ETA: 12s - loss: 0.2312 - binary_accuracy: 0.9244 - dice_coef: 0.80 - ETA: 12s - loss: 0.2290 - binary_accuracy: 0.9253 - dice_coef: 0.80 - ETA: 11s - loss: 0.2336 - binary_accuracy: 0.9253 - dice_coef: 0.80 - ETA: 11s - loss: 0.2340 - binary_accuracy: 0.9257 - dice_coef: 0.80 - ETA: 11s - loss: 0.2338 - binary_accuracy: 0.9262 - dice_coef: 0.80 - ETA: 11s - loss: 0.2331 - binary_accuracy: 0.9261 - dice_coef: 0.80 - ETA: 11s - loss: 0.2334 - binary_accuracy: 0.9265 - dice_coef: 0.80 - ETA: 11s - loss: 0.2333 - binary_accuracy: 0.9258 - dice_coef: 0.80 - ETA: 11s - loss: 0.2339 - binary_accuracy: 0.9251 - dice_coef: 0.80 - ETA: 10s - loss: 0.2316 - binary_accuracy: 0.9241 - dice_coef: 0.80 - ETA: 10s - loss: 0.2341 - binary_accuracy: 0.9237 - dice_coef: 0.79 - ETA: 10s - loss: 0.2338 - binary_accuracy: 0.9233 - dice_coef: 0.79 - ETA: 10s - loss: 0.2370 - binary_accuracy: 0.9235 - dice_coef: 0.79 - ETA: 10s - loss: 0.2375 - binary_accuracy: 0.9219 - dice_coef: 0.79 - ETA: 10s - loss: 0.2384 - binary_accuracy: 0.9227 - dice_coef: 0.79 - ETA: 10s - loss: 0.2387 - binary_accuracy: 0.9219 - dice_coef: 0.79 - ETA: 9s - loss: 0.2382 - binary_accuracy: 0.9219 - dice_coef: 0.7957 - ETA: 9s - loss: 0.2371 - binary_accuracy: 0.9216 - dice_coef: 0.796 - ETA: 9s - loss: 0.2393 - binary_accuracy: 0.9223 - dice_coef: 0.794 - ETA: 9s - loss: 0.2385 - binary_accuracy: 0.9220 - dice_coef: 0.795 - ETA: 9s - loss: 0.2373 - binary_accuracy: 0.9227 - dice_coef: 0.796 - ETA: 9s - loss: 0.2398 - binary_accuracy: 0.9220 - dice_coef: 0.794 - ETA: 9s - loss: 0.2396 - binary_accuracy: 0.9215 - dice_coef: 0.793 - ETA: 8s - loss: 0.2403 - binary_accuracy: 0.9220 - dice_coef: 0.793 - ETA: 8s - loss: 0.2402 - binary_accuracy: 0.9220 - dice_coef: 0.793 - ETA: 8s - loss: 0.2399 - binary_accuracy: 0.9219 - dice_coef: 0.793 - ETA: 8s - loss: 0.2394 - binary_accuracy: 0.9219 - dice_coef: 0.794 - ETA: 8s - loss: 0.2393 - binary_accuracy: 0.9214 - dice_coef: 0.793 - ETA: 8s - loss: 0.2407 - binary_accuracy: 0.9199 - dice_coef: 0.792 - ETA: 8s - loss: 0.2399 - binary_accuracy: 0.9196 - dice_coef: 0.792 - ETA: 8s - loss: 0.2400 - binary_accuracy: 0.9194 - dice_coef: 0.792 - ETA: 7s - loss: 0.2397 - binary_accuracy: 0.9199 - dice_coef: 0.792 - ETA: 7s - loss: 0.2391 - binary_accuracy: 0.9195 - dice_coef: 0.792 - ETA: 7s - loss: 0.2389 - binary_accuracy: 0.9194 - dice_coef: 0.792 - ETA: 7s - loss: 0.2388 - binary_accuracy: 0.9191 - dice_coef: 0.792 - ETA: 7s - loss: 0.2388 - binary_accuracy: 0.9194 - dice_coef: 0.792 - ETA: 7s - loss: 0.2378 - binary_accuracy: 0.9197 - dice_coef: 0.793 - ETA: 7s - loss: 0.2386 - binary_accuracy: 0.9195 - dice_coef: 0.792 - ETA: 6s - loss: 0.2380 - binary_accuracy: 0.9194 - dice_coef: 0.792 - ETA: 6s - loss: 0.2376 - binary_accuracy: 0.9192 - dice_coef: 0.792 - ETA: 6s - loss: 0.2377 - binary_accuracy: 0.9187 - dice_coef: 0.792 - ETA: 6s - loss: 0.2372 - binary_accuracy: 0.9184 - dice_coef: 0.792 - ETA: 6s - loss: 0.2376 - binary_accuracy: 0.9184 - dice_coef: 0.791 - ETA: 6s - loss: 0.2366 - binary_accuracy: 0.9182 - dice_coef: 0.792 - ETA: 6s - loss: 0.2367 - binary_accuracy: 0.9185 - dice_coef: 0.792 - ETA: 6s - loss: 0.2361 - binary_accuracy: 0.9183 - dice_coef: 0.792 - ETA: 5s - loss: 0.2358 - binary_accuracy: 0.9187 - dice_coef: 0.793 - ETA: 5s - loss: 0.2355 - binary_accu ...
#
# Epoch 00003: val_loss improved from 0.23201 to 0.19272, saving model to ./keras_DRIVE_Binary.model
# Epoch 4/15
# 100/100 [==============================] - ETA: 13s - loss: 0.2123 - binary_accuracy: 0.9053 - dice_coef: 0.80 - ETA: 12s - loss: 0.2426 - binary_accuracy: 0.8943 - dice_coef: 0.77 - ETA: 12s - loss: 0.2523 - binary_accuracy: 0.9020 - dice_coef: 0.76 - ETA: 12s - loss: 0.2364 - binary_accuracy: 0.9053 - dice_coef: 0.77 - ETA: 12s - loss: 0.2307 - binary_accuracy: 0.9093 - dice_coef: 0.78 - ETA: 12s - loss: 0.2221 - binary_accuracy: 0.9105 - dice_coef: 0.79 - ETA: 12s - loss: 0.2189 - binary_accuracy: 0.9133 - dice_coef: 0.79 - ETA: 12s - loss: 0.2145 - binary_accuracy: 0.9167 - dice_coef: 0.80 - ETA: 12s - loss: 0.2121 - binary_accuracy: 0.9170 - dice_coef: 0.80 - ETA: 12s - loss: 0.2115 - binary_accuracy: 0.9189 - dice_coef: 0.80 - ETA: 11s - loss: 0.2125 - binary_accuracy: 0.9193 - dice_coef: 0.80 - ETA: 11s - loss: 0.2107 - binary_accuracy: 0.9194 - dice_coef: 0.80 - ETA: 11s - loss: 0.2099 - binary_accuracy: 0.9207 - dice_coef: 0.80 - ETA: 11s - loss: 0.2089 - binary_accuracy: 0.9217 - dice_coef: 0.80 - ETA: 11s - loss: 0.2093 - binary_accuracy: 0.9236 - dice_coef: 0.80 - ETA: 11s - loss: 0.2093 - binary_accuracy: 0.9231 - dice_coef: 0.80 - ETA: 11s - loss: 0.2063 - binary_accuracy: 0.9238 - dice_coef: 0.80 - ETA: 10s - loss: 0.2065 - binary_accuracy: 0.9230 - dice_coef: 0.80 - ETA: 10s - loss: 0.2071 - binary_accuracy: 0.9231 - dice_coef: 0.80 - ETA: 10s - loss: 0.2109 - binary_accuracy: 0.9237 - dice_coef: 0.80 - ETA: 10s - loss: 0.2107 - binary_accuracy: 0.9246 - dice_coef: 0.80 - ETA: 10s - loss: 0.2093 - binary_accuracy: 0.9254 - dice_coef: 0.80 - ETA: 10s - loss: 0.2087 - binary_accuracy: 0.9253 - dice_coef: 0.80 - ETA: 10s - loss: 0.2071 - binary_accuracy: 0.9255 - dice_coef: 0.80 - ETA: 10s - loss: 0.2052 - binary_accuracy: 0.9264 - dice_coef: 0.81 - ETA: 9s - loss: 0.2051 - binary_accuracy: 0.9266 - dice_coef: 0.8106 - ETA: 9s - loss: 0.2051 - binary_accuracy: 0.9252 - dice_coef: 0.810 - ETA: 9s - loss: 0.2047 - binary_accuracy: 0.9248 - dice_coef: 0.810 - ETA: 9s - loss: 0.2046 - binary_accuracy: 0.9252 - dice_coef: 0.810 - ETA: 9s - loss: 0.2035 - binary_accuracy: 0.9251 - dice_coef: 0.811 - ETA: 9s - loss: 0.2032 - binary_accuracy: 0.9245 - dice_coef: 0.811 - ETA: 9s - loss: 0.2033 - binary_accuracy: 0.9238 - dice_coef: 0.811 - ETA: 8s - loss: 0.2020 - binary_accuracy: 0.9243 - dice_coef: 0.812 - ETA: 8s - loss: 0.2025 - binary_accuracy: 0.9245 - dice_coef: 0.812 - ETA: 8s - loss: 0.2056 - binary_accuracy: 0.9246 - dice_coef: 0.809 - ETA: 8s - loss: 0.2060 - binary_accuracy: 0.9247 - dice_coef: 0.808 - ETA: 8s - loss: 0.2053 - binary_accuracy: 0.9248 - dice_coef: 0.809 - ETA: 8s - loss: 0.2046 - binary_accuracy: 0.9249 - dice_coef: 0.810 - ETA: 8s - loss: 0.2036 - binary_accuracy: 0.9252 - dice_coef: 0.811 - ETA: 8s - loss: 0.2030 - binary_accuracy: 0.9250 - dice_coef: 0.811 - ETA: 7s - loss: 0.2020 - binary_accuracy: 0.9251 - dice_coef: 0.812 - ETA: 7s - loss: 0.2018 - binary_accuracy: 0.9249 - dice_coef: 0.812 - ETA: 7s - loss: 0.2017 - binary_accuracy: 0.9255 - dice_coef: 0.812 - ETA: 7s - loss: 0.2012 - binary_accuracy: 0.9253 - dice_coef: 0.813 - ETA: 7s - loss: 0.2008 - binary_accuracy: 0.9256 - dice_coef: 0.813 - ETA: 7s - loss: 0.2016 - binary_accuracy: 0.9259 - dice_coef: 0.812 - ETA: 7s - loss: 0.2012 - binary_accuracy: 0.9259 - dice_coef: 0.813 - ETA: 6s - loss: 0.2008 - binary_accuracy: 0.9256 - dice_coef: 0.813 - ETA: 6s - loss: 0.2003 - binary_accuracy: 0.9252 - dice_coef: 0.813 - ETA: 6s - loss: 0.1998 - binary_accuracy: 0.9250 - dice_coef: 0.814 - ETA: 6s - loss: 0.1993 - binary_accuracy: 0.9251 - dice_coef: 0.814 - ETA: 6s - loss: 0.1993 - binary_accuracy: 0.9247 - dice_coef: 0.814 - ETA: 6s - loss: 0.2002 - binary_accuracy: 0.9242 - dice_coef: 0.813 - ETA: 6s - loss: 0.2008 - binary_accuracy: 0.9242 - dice_coef: 0.812 - ETA: 6s - loss: 0.2002 - binary_accuracy: 0.9239 - dice_coef: 0.813 - ETA: 5s - loss: 0.2001 - binary_accuracy: 0.9237 - dice_coef: 0.813 - ETA: 5s - loss: 0.1998 - binary_accu ...
#
# Epoch 00004: val_loss improved from 0.19272 to 0.18058, saving model to ./keras_DRIVE_Binary.model
# Epoch 5/15
# 100/100 [==============================] - ETA: 13s - loss: 0.1790 - binary_accuracy: 0.9267 - dice_coef: 0.83 - ETA: 12s - loss: 0.1747 - binary_accuracy: 0.9270 - dice_coef: 0.83 - ETA: 12s - loss: 0.1828 - binary_accuracy: 0.9223 - dice_coef: 0.82 - ETA: 12s - loss: 0.1971 - binary_accuracy: 0.9206 - dice_coef: 0.81 - ETA: 12s - loss: 0.2033 - binary_accuracy: 0.9203 - dice_coef: 0.80 - ETA: 12s - loss: 0.2012 - binary_accuracy: 0.9189 - dice_coef: 0.80 - ETA: 12s - loss: 0.1983 - binary_accuracy: 0.9191 - dice_coef: 0.81 - ETA: 12s - loss: 0.1971 - binary_accuracy: 0.9208 - dice_coef: 0.81 - ETA: 12s - loss: 0.1964 - binary_accuracy: 0.9211 - dice_coef: 0.81 - ETA: 12s - loss: 0.1960 - binary_accuracy: 0.9223 - dice_coef: 0.81 - ETA: 11s - loss: 0.1938 - binary_accuracy: 0.9213 - dice_coef: 0.81 - ETA: 11s - loss: 0.1953 - binary_accuracy: 0.9213 - dice_coef: 0.81 - ETA: 11s - loss: 0.1923 - binary_accuracy: 0.9221 - dice_coef: 0.81 - ETA: 11s - loss: 0.1907 - binary_accuracy: 0.9234 - dice_coef: 0.81 - ETA: 11s - loss: 0.1908 - binary_accuracy: 0.9239 - dice_coef: 0.81 - ETA: 11s - loss: 0.1896 - binary_accuracy: 0.9246 - dice_coef: 0.82 - ETA: 11s - loss: 0.1915 - binary_accuracy: 0.9247 - dice_coef: 0.81 - ETA: 10s - loss: 0.1901 - binary_accuracy: 0.9253 - dice_coef: 0.81 - ETA: 10s - loss: 0.1891 - binary_accuracy: 0.9261 - dice_coef: 0.82 - ETA: 10s - loss: 0.1941 - binary_accuracy: 0.9253 - dice_coef: 0.81 - ETA: 10s - loss: 0.1948 - binary_accuracy: 0.9247 - dice_coef: 0.81 - ETA: 10s - loss: 0.1957 - binary_accuracy: 0.9245 - dice_coef: 0.81 - ETA: 10s - loss: 0.1944 - binary_accuracy: 0.9256 - dice_coef: 0.81 - ETA: 10s - loss: 0.1942 - binary_accuracy: 0.9249 - dice_coef: 0.81 - ETA: 10s - loss: 0.1935 - binary_accuracy: 0.9246 - dice_coef: 0.81 - ETA: 9s - loss: 0.1936 - binary_accuracy: 0.9243 - dice_coef: 0.8161 - ETA: 9s - loss: 0.1930 - binary_accuracy: 0.9250 - dice_coef: 0.816 - ETA: 9s - loss: 0.1925 - binary_accuracy: 0.9256 - dice_coef: 0.817 - ETA: 9s - loss: 0.1920 - binary_accuracy: 0.9258 - dice_coef: 0.817 - ETA: 9s - loss: 0.1915 - binary_accuracy: 0.9251 - dice_coef: 0.818 - ETA: 9s - loss: 0.1911 - binary_accuracy: 0.9253 - dice_coef: 0.818 - ETA: 9s - loss: 0.1904 - binary_accuracy: 0.9257 - dice_coef: 0.819 - ETA: 8s - loss: 0.1897 - binary_accuracy: 0.9260 - dice_coef: 0.819 - ETA: 8s - loss: 0.1907 - binary_accuracy: 0.9255 - dice_coef: 0.818 - ETA: 8s - loss: 0.1921 - binary_accuracy: 0.9254 - dice_coef: 0.817 - ETA: 8s - loss: 0.1925 - binary_accuracy: 0.9249 - dice_coef: 0.817 - ETA: 8s - loss: 0.1921 - binary_accuracy: 0.9246 - dice_coef: 0.817 - ETA: 8s - loss: 0.1918 - binary_accuracy: 0.9247 - dice_coef: 0.817 - ETA: 8s - loss: 0.1919 - binary_accuracy: 0.9245 - dice_coef: 0.817 - ETA: 8s - loss: 0.1931 - binary_accuracy: 0.9247 - dice_coef: 0.816 - ETA: 7s - loss: 0.1925 - binary_accuracy: 0.9247 - dice_coef: 0.817 - ETA: 7s - loss: 0.1921 - binary_accuracy: 0.9244 - dice_coef: 0.817 - ETA: 7s - loss: 0.1916 - binary_accuracy: 0.9249 - dice_coef: 0.817 - ETA: 7s - loss: 0.1922 - binary_accuracy: 0.9244 - dice_coef: 0.817 - ETA: 7s - loss: 0.1931 - binary_accuracy: 0.9240 - dice_coef: 0.816 - ETA: 7s - loss: 0.1930 - binary_accuracy: 0.9235 - dice_coef: 0.816 - ETA: 7s - loss: 0.1931 - binary_accuracy: 0.9232 - dice_coef: 0.816 - ETA: 6s - loss: 0.1929 - binary_accuracy: 0.9234 - dice_coef: 0.816 - ETA: 6s - loss: 0.1936 - binary_accuracy: 0.9234 - dice_coef: 0.815 - ETA: 6s - loss: 0.1934 - binary_accuracy: 0.9237 - dice_coef: 0.815 - ETA: 6s - loss: 0.1929 - binary_accuracy: 0.9239 - dice_coef: 0.816 - ETA: 6s - loss: 0.1925 - binary_accuracy: 0.9239 - dice_coef: 0.816 - ETA: 6s - loss: 0.1922 - binary_accuracy: 0.9239 - dice_coef: 0.816 - ETA: 6s - loss: 0.1922 - binary_accuracy: 0.9241 - dice_coef: 0.816 - ETA: 6s - loss: 0.1918 - binary_accuracy: 0.9241 - dice_coef: 0.817 - ETA: 5s - loss: 0.1914 - binary_accuracy: 0.9240 - dice_coef: 0.817 - ETA: 5s - loss: 0.1911 - binary_accu ...
#
# Epoch 00005: val_loss did not improve
# Epoch 6/15
# 100/100 [==============================] - ETA: 13s - loss: 0.1764 - binary_accuracy: 0.9358 - dice_coef: 0.83 - ETA: 13s - loss: 0.1841 - binary_accuracy: 0.9263 - dice_coef: 0.82 - ETA: 12s - loss: 0.1996 - binary_accuracy: 0.9279 - dice_coef: 0.80 - ETA: 12s - loss: 0.1962 - binary_accuracy: 0.9258 - dice_coef: 0.81 - ETA: 12s - loss: 0.1915 - binary_accuracy: 0.9304 - dice_coef: 0.81 - ETA: 12s - loss: 0.1961 - binary_accuracy: 0.9329 - dice_coef: 0.81 - ETA: 12s - loss: 0.1944 - binary_accuracy: 0.9310 - dice_coef: 0.81 - ETA: 12s - loss: 0.2062 - binary_accuracy: 0.9273 - dice_coef: 0.80 - ETA: 12s - loss: 0.2034 - binary_accuracy: 0.9284 - dice_coef: 0.80 - ETA: 12s - loss: 0.2011 - binary_accuracy: 0.9285 - dice_coef: 0.80 - ETA: 11s - loss: 0.2034 - binary_accuracy: 0.9292 - dice_coef: 0.80 - ETA: 11s - loss: 0.2028 - binary_accuracy: 0.9281 - dice_coef: 0.80 - ETA: 11s - loss: 0.2110 - binary_accuracy: 0.9283 - dice_coef: 0.79 - ETA: 11s - loss: 0.2116 - binary_accuracy: 0.9284 - dice_coef: 0.79 - ETA: 11s - loss: 0.2102 - binary_accuracy: 0.9259 - dice_coef: 0.79 - ETA: 11s - loss: 0.2106 - binary_accuracy: 0.9252 - dice_coef: 0.79 - ETA: 11s - loss: 0.2086 - binary_accuracy: 0.9246 - dice_coef: 0.79 - ETA: 11s - loss: 0.2093 - binary_accuracy: 0.9250 - dice_coef: 0.79 - ETA: 10s - loss: 0.2097 - binary_accuracy: 0.9233 - dice_coef: 0.79 - ETA: 10s - loss: 0.2084 - binary_accuracy: 0.9225 - dice_coef: 0.79 - ETA: 10s - loss: 0.2075 - binary_accuracy: 0.9223 - dice_coef: 0.79 - ETA: 10s - loss: 0.2062 - binary_accuracy: 0.9220 - dice_coef: 0.80 - ETA: 10s - loss: 0.2043 - binary_accuracy: 0.9222 - dice_coef: 0.80 - ETA: 10s - loss: 0.2033 - binary_accuracy: 0.9224 - dice_coef: 0.80 - ETA: 10s - loss: 0.2035 - binary_accuracy: 0.9218 - dice_coef: 0.80 - ETA: 9s - loss: 0.2050 - binary_accuracy: 0.9211 - dice_coef: 0.8020 - ETA: 9s - loss: 0.2067 - binary_accuracy: 0.9208 - dice_coef: 0.800 - ETA: 9s - loss: 0.2071 - binary_accuracy: 0.9199 - dice_coef: 0.799 - ETA: 9s - loss: 0.2100 - binary_accuracy: 0.9189 - dice_coef: 0.796 - ETA: 9s - loss: 0.2091 - binary_accuracy: 0.9186 - dice_coef: 0.797 - ETA: 9s - loss: 0.2080 - binary_accuracy: 0.9196 - dice_coef: 0.798 - ETA: 9s - loss: 0.2073 - binary_accuracy: 0.9200 - dice_coef: 0.799 - ETA: 9s - loss: 0.2073 - binary_accuracy: 0.9200 - dice_coef: 0.799 - ETA: 8s - loss: 0.2063 - binary_accuracy: 0.9197 - dice_coef: 0.800 - ETA: 8s - loss: 0.2059 - binary_accuracy: 0.9195 - dice_coef: 0.800 - ETA: 8s - loss: 0.2049 - binary_accuracy: 0.9198 - dice_coef: 0.801 - ETA: 8s - loss: 0.2037 - binary_accuracy: 0.9201 - dice_coef: 0.802 - ETA: 8s - loss: 0.2030 - binary_accuracy: 0.9201 - dice_coef: 0.803 - ETA: 8s - loss: 0.2021 - binary_accuracy: 0.9202 - dice_coef: 0.804 - ETA: 8s - loss: 0.2017 - binary_accuracy: 0.9198 - dice_coef: 0.804 - ETA: 7s - loss: 0.2005 - binary_accuracy: 0.9196 - dice_coef: 0.806 - ETA: 7s - loss: 0.2012 - binary_accuracy: 0.9196 - dice_coef: 0.805 - ETA: 7s - loss: 0.2010 - binary_accuracy: 0.9197 - dice_coef: 0.805 - ETA: 7s - loss: 0.2012 - binary_accuracy: 0.9196 - dice_coef: 0.805 - ETA: 7s - loss: 0.2015 - binary_accuracy: 0.9199 - dice_coef: 0.805 - ETA: 7s - loss: 0.2012 - binary_accuracy: 0.9203 - dice_coef: 0.805 - ETA: 7s - loss: 0.2003 - binary_accuracy: 0.9207 - dice_coef: 0.806 - ETA: 6s - loss: 0.1999 - binary_accuracy: 0.9208 - dice_coef: 0.806 - ETA: 6s - loss: 0.1991 - binary_accuracy: 0.9211 - dice_coef: 0.807 - ETA: 6s - loss: 0.1994 - binary_accuracy: 0.9209 - dice_coef: 0.807 - ETA: 6s - loss: 0.1989 - binary_accuracy: 0.9216 - dice_coef: 0.807 - ETA: 6s - loss: 0.1988 - binary_accuracy: 0.9217 - dice_coef: 0.807 - ETA: 6s - loss: 0.1985 - binary_accuracy: 0.9219 - dice_coef: 0.808 - ETA: 6s - loss: 0.1985 - binary_accuracy: 0.9216 - dice_coef: 0.807 - ETA: 6s - loss: 0.1979 - binary_accuracy: 0.9218 - dice_coef: 0.808 - ETA: 5s - loss: 0.1980 - binary_accuracy: 0.9216 - dice_coef: 0.808 - ETA: 5s - loss: 0.1978 - binary_accu ...
#
# Epoch 00006: val_loss improved from 0.18058 to 0.17117, saving model to ./keras_DRIVE_Binary.model
# Epoch 7/15
# 100/100 [==============================] - ETA: 13s - loss: 0.1907 - binary_accuracy: 0.9276 - dice_coef: 0.81 - ETA: 13s - loss: 0.1816 - binary_accuracy: 0.9316 - dice_coef: 0.82 - ETA: 13s - loss: 0.1892 - binary_accuracy: 0.9321 - dice_coef: 0.81 - ETA: 12s - loss: 0.1813 - binary_accuracy: 0.9328 - dice_coef: 0.82 - ETA: 12s - loss: 0.1826 - binary_accuracy: 0.9328 - dice_coef: 0.82 - ETA: 12s - loss: 0.1915 - binary_accuracy: 0.9338 - dice_coef: 0.81 - ETA: 12s - loss: 0.1883 - binary_accuracy: 0.9314 - dice_coef: 0.81 - ETA: 12s - loss: 0.1869 - binary_accuracy: 0.9328 - dice_coef: 0.81 - ETA: 12s - loss: 0.1880 - binary_accuracy: 0.9329 - dice_coef: 0.81 - ETA: 12s - loss: 0.1858 - binary_accuracy: 0.9334 - dice_coef: 0.82 - ETA: 12s - loss: 0.1916 - binary_accuracy: 0.9314 - dice_coef: 0.81 - ETA: 11s - loss: 0.1920 - binary_accuracy: 0.9296 - dice_coef: 0.81 - ETA: 11s - loss: 0.1916 - binary_accuracy: 0.9303 - dice_coef: 0.81 - ETA: 11s - loss: 0.1901 - binary_accuracy: 0.9305 - dice_coef: 0.81 - ETA: 11s - loss: 0.1898 - binary_accuracy: 0.9291 - dice_coef: 0.81 - ETA: 11s - loss: 0.1915 - binary_accuracy: 0.9278 - dice_coef: 0.81 - ETA: 11s - loss: 0.1908 - binary_accuracy: 0.9277 - dice_coef: 0.81 - ETA: 11s - loss: 0.1919 - binary_accuracy: 0.9270 - dice_coef: 0.81 - ETA: 10s - loss: 0.1926 - binary_accuracy: 0.9255 - dice_coef: 0.81 - ETA: 10s - loss: 0.1948 - binary_accuracy: 0.9235 - dice_coef: 0.81 - ETA: 10s - loss: 0.1938 - binary_accuracy: 0.9240 - dice_coef: 0.81 - ETA: 10s - loss: 0.1930 - binary_accuracy: 0.9245 - dice_coef: 0.81 - ETA: 10s - loss: 0.1944 - binary_accuracy: 0.9247 - dice_coef: 0.81 - ETA: 10s - loss: 0.1934 - binary_accuracy: 0.9248 - dice_coef: 0.81 - ETA: 10s - loss: 0.1953 - binary_accuracy: 0.9253 - dice_coef: 0.80 - ETA: 10s - loss: 0.1944 - binary_accuracy: 0.9248 - dice_coef: 0.81 - ETA: 9s - loss: 0.1949 - binary_accuracy: 0.9249 - dice_coef: 0.8104 - ETA: 9s - loss: 0.1941 - binary_accuracy: 0.9255 - dice_coef: 0.811 - ETA: 9s - loss: 0.1948 - binary_accuracy: 0.9257 - dice_coef: 0.810 - ETA: 9s - loss: 0.1963 - binary_accuracy: 0.9253 - dice_coef: 0.809 - ETA: 9s - loss: 0.1957 - binary_accuracy: 0.9258 - dice_coef: 0.809 - ETA: 9s - loss: 0.1957 - binary_accuracy: 0.9258 - dice_coef: 0.809 - ETA: 9s - loss: 0.1955 - binary_accuracy: 0.9251 - dice_coef: 0.809 - ETA: 8s - loss: 0.1949 - binary_accuracy: 0.9255 - dice_coef: 0.810 - ETA: 8s - loss: 0.1939 - binary_accuracy: 0.9259 - dice_coef: 0.811 - ETA: 8s - loss: 0.1935 - binary_accuracy: 0.9262 - dice_coef: 0.811 - ETA: 8s - loss: 0.1926 - binary_accuracy: 0.9257 - dice_coef: 0.812 - ETA: 8s - loss: 0.1919 - binary_accuracy: 0.9257 - dice_coef: 0.813 - ETA: 8s - loss: 0.1917 - binary_accuracy: 0.9256 - dice_coef: 0.813 - ETA: 8s - loss: 0.1924 - binary_accuracy: 0.9255 - dice_coef: 0.812 - ETA: 7s - loss: 0.1928 - binary_accuracy: 0.9254 - dice_coef: 0.812 - ETA: 7s - loss: 0.1921 - binary_accuracy: 0.9259 - dice_coef: 0.813 - ETA: 7s - loss: 0.1923 - binary_accuracy: 0.9263 - dice_coef: 0.812 - ETA: 7s - loss: 0.1920 - binary_accuracy: 0.9265 - dice_coef: 0.813 - ETA: 7s - loss: 0.1911 - binary_accuracy: 0.9266 - dice_coef: 0.813 - ETA: 7s - loss: 0.1902 - binary_accuracy: 0.9269 - dice_coef: 0.814 - ETA: 7s - loss: 0.1908 - binary_accuracy: 0.9265 - dice_coef: 0.814 - ETA: 7s - loss: 0.1912 - binary_accuracy: 0.9258 - dice_coef: 0.813 - ETA: 6s - loss: 0.1916 - binary_accuracy: 0.9259 - dice_coef: 0.813 - ETA: 6s - loss: 0.1917 - binary_accuracy: 0.9256 - dice_coef: 0.813 - ETA: 6s - loss: 0.1910 - binary_accuracy: 0.9261 - dice_coef: 0.814 - ETA: 6s - loss: 0.1913 - binary_accuracy: 0.9261 - dice_coef: 0.813 - ETA: 6s - loss: 0.1909 - binary_accuracy: 0.9261 - dice_coef: 0.814 - ETA: 6s - loss: 0.1908 - binary_accuracy: 0.9262 - dice_coef: 0.814 - ETA: 6s - loss: 0.1906 - binary_accuracy: 0.9263 - dice_coef: 0.814 - ETA: 5s - loss: 0.1907 - binary_accuracy: 0.9262 - dice_coef: 0.814 - ETA: 5s - loss: 0.1902 - binary_accu ...
#
# Epoch 00007: val_loss did not improve
# Epoch 8/15
# 100/100 [==============================] - ETA: 13s - loss: 0.1762 - binary_accuracy: 0.9061 - dice_coef: 0.82 - ETA: 13s - loss: 0.1763 - binary_accuracy: 0.9175 - dice_coef: 0.82 - ETA: 12s - loss: 0.1756 - binary_accuracy: 0.9193 - dice_coef: 0.82 - ETA: 12s - loss: 0.1763 - binary_accuracy: 0.9164 - dice_coef: 0.82 - ETA: 12s - loss: 0.1741 - binary_accuracy: 0.9149 - dice_coef: 0.82 - ETA: 12s - loss: 0.1793 - binary_accuracy: 0.9179 - dice_coef: 0.82 - ETA: 12s - loss: 0.1793 - binary_accuracy: 0.9196 - dice_coef: 0.82 - ETA: 12s - loss: 0.1820 - binary_accuracy: 0.9193 - dice_coef: 0.82 - ETA: 12s - loss: 0.1831 - binary_accuracy: 0.9179 - dice_coef: 0.82 - ETA: 12s - loss: 0.1803 - binary_accuracy: 0.9209 - dice_coef: 0.82 - ETA: 11s - loss: 0.1840 - binary_accuracy: 0.9190 - dice_coef: 0.81 - ETA: 11s - loss: 0.1826 - binary_accuracy: 0.9190 - dice_coef: 0.82 - ETA: 11s - loss: 0.1826 - binary_accuracy: 0.9176 - dice_coef: 0.82 - ETA: 11s - loss: 0.1818 - binary_accuracy: 0.9178 - dice_coef: 0.82 - ETA: 11s - loss: 0.1796 - binary_accuracy: 0.9198 - dice_coef: 0.82 - ETA: 11s - loss: 0.1799 - binary_accuracy: 0.9197 - dice_coef: 0.82 - ETA: 11s - loss: 0.1786 - binary_accuracy: 0.9216 - dice_coef: 0.82 - ETA: 11s - loss: 0.1782 - binary_accuracy: 0.9216 - dice_coef: 0.82 - ETA: 10s - loss: 0.1797 - binary_accuracy: 0.9208 - dice_coef: 0.82 - ETA: 10s - loss: 0.1782 - binary_accuracy: 0.9216 - dice_coef: 0.82 - ETA: 10s - loss: 0.1766 - binary_accuracy: 0.9220 - dice_coef: 0.82 - ETA: 10s - loss: 0.1760 - binary_accuracy: 0.9219 - dice_coef: 0.82 - ETA: 10s - loss: 0.1776 - binary_accuracy: 0.9224 - dice_coef: 0.82 - ETA: 10s - loss: 0.1783 - binary_accuracy: 0.9222 - dice_coef: 0.82 - ETA: 10s - loss: 0.1789 - binary_accuracy: 0.9232 - dice_coef: 0.82 - ETA: 9s - loss: 0.1789 - binary_accuracy: 0.9224 - dice_coef: 0.8246 - ETA: 9s - loss: 0.1797 - binary_accuracy: 0.9215 - dice_coef: 0.823 - ETA: 9s - loss: 0.1800 - binary_accuracy: 0.9212 - dice_coef: 0.823 - ETA: 9s - loss: 0.1803 - binary_accuracy: 0.9215 - dice_coef: 0.823 - ETA: 9s - loss: 0.1796 - binary_accuracy: 0.9216 - dice_coef: 0.823 - ETA: 9s - loss: 0.1798 - binary_accuracy: 0.9211 - dice_coef: 0.823 - ETA: 9s - loss: 0.1816 - binary_accuracy: 0.9209 - dice_coef: 0.821 - ETA: 9s - loss: 0.1813 - binary_accuracy: 0.9216 - dice_coef: 0.822 - ETA: 8s - loss: 0.1810 - binary_accuracy: 0.9214 - dice_coef: 0.822 - ETA: 8s - loss: 0.1806 - binary_accuracy: 0.9216 - dice_coef: 0.822 - ETA: 8s - loss: 0.1825 - binary_accuracy: 0.9222 - dice_coef: 0.821 - ETA: 8s - loss: 0.1831 - binary_accuracy: 0.9215 - dice_coef: 0.820 - ETA: 8s - loss: 0.1824 - binary_accuracy: 0.9220 - dice_coef: 0.821 - ETA: 8s - loss: 0.1821 - binary_accuracy: 0.9218 - dice_coef: 0.821 - ETA: 8s - loss: 0.1819 - binary_accuracy: 0.9216 - dice_coef: 0.821 - ETA: 7s - loss: 0.1830 - binary_accuracy: 0.9219 - dice_coef: 0.820 - ETA: 7s - loss: 0.1825 - binary_accuracy: 0.9218 - dice_coef: 0.821 - ETA: 7s - loss: 0.1819 - binary_accuracy: 0.9220 - dice_coef: 0.821 - ETA: 7s - loss: 0.1821 - binary_accuracy: 0.9222 - dice_coef: 0.821 - ETA: 7s - loss: 0.1817 - binary_accuracy: 0.9223 - dice_coef: 0.821 - ETA: 7s - loss: 0.1819 - binary_accuracy: 0.9214 - dice_coef: 0.821 - ETA: 7s - loss: 0.1815 - binary_accuracy: 0.9218 - dice_coef: 0.822 - ETA: 7s - loss: 0.1811 - binary_accuracy: 0.9218 - dice_coef: 0.822 - ETA: 6s - loss: 0.1807 - binary_accuracy: 0.9223 - dice_coef: 0.822 - ETA: 6s - loss: 0.1801 - binary_accuracy: 0.9227 - dice_coef: 0.823 - ETA: 6s - loss: 0.1801 - binary_accuracy: 0.9225 - dice_coef: 0.823 - ETA: 6s - loss: 0.1801 - binary_accuracy: 0.9225 - dice_coef: 0.823 - ETA: 6s - loss: 0.1797 - binary_accuracy: 0.9226 - dice_coef: 0.823 - ETA: 6s - loss: 0.1792 - binary_accuracy: 0.9229 - dice_coef: 0.824 - ETA: 6s - loss: 0.1797 - binary_accuracy: 0.9232 - dice_coef: 0.823 - ETA: 5s - loss: 0.1795 - binary_accuracy: 0.9233 - dice_coef: 0.824 - ETA: 5s - loss: 0.1800 - binary_accu ...
#
# Epoch 00008: val_loss improved from 0.17117 to 0.16880, saving model to ./keras_DRIVE_Binary.model
# Epoch 9/15
# 100/100 [==============================] - ETA: 13s - loss: 0.1627 - binary_accuracy: 0.9181 - dice_coef: 0.83 - ETA: 13s - loss: 0.1603 - binary_accuracy: 0.9277 - dice_coef: 0.84 - ETA: 12s - loss: 0.1674 - binary_accuracy: 0.9262 - dice_coef: 0.83 - ETA: 12s - loss: 0.1625 - binary_accuracy: 0.9276 - dice_coef: 0.84 - ETA: 12s - loss: 0.1623 - binary_accuracy: 0.9313 - dice_coef: 0.84 - ETA: 12s - loss: 0.1677 - binary_accuracy: 0.9281 - dice_coef: 0.83 - ETA: 12s - loss: 0.1676 - binary_accuracy: 0.9286 - dice_coef: 0.83 - ETA: 12s - loss: 0.1715 - binary_accuracy: 0.9273 - dice_coef: 0.83 - ETA: 12s - loss: 0.1699 - binary_accuracy: 0.9292 - dice_coef: 0.83 - ETA: 12s - loss: 0.1703 - binary_accuracy: 0.9294 - dice_coef: 0.83 - ETA: 11s - loss: 0.1728 - binary_accuracy: 0.9253 - dice_coef: 0.82 - ETA: 11s - loss: 0.1716 - binary_accuracy: 0.9259 - dice_coef: 0.83 - ETA: 11s - loss: 0.1713 - binary_accuracy: 0.9266 - dice_coef: 0.83 - ETA: 11s - loss: 0.1707 - binary_accuracy: 0.9267 - dice_coef: 0.83 - ETA: 11s - loss: 0.1707 - binary_accuracy: 0.9268 - dice_coef: 0.83 - ETA: 11s - loss: 0.1739 - binary_accuracy: 0.9259 - dice_coef: 0.82 - ETA: 11s - loss: 0.1754 - binary_accuracy: 0.9262 - dice_coef: 0.82 - ETA: 10s - loss: 0.1734 - binary_accuracy: 0.9280 - dice_coef: 0.82 - ETA: 10s - loss: 0.1729 - binary_accuracy: 0.9289 - dice_coef: 0.82 - ETA: 10s - loss: 0.1726 - binary_accuracy: 0.9288 - dice_coef: 0.83 - ETA: 10s - loss: 0.1725 - binary_accuracy: 0.9276 - dice_coef: 0.83 - ETA: 10s - loss: 0.1715 - binary_accuracy: 0.9287 - dice_coef: 0.83 - ETA: 10s - loss: 0.1711 - binary_accuracy: 0.9285 - dice_coef: 0.83 - ETA: 10s - loss: 0.1707 - binary_accuracy: 0.9290 - dice_coef: 0.83 - ETA: 9s - loss: 0.1702 - binary_accuracy: 0.9288 - dice_coef: 0.8326 - ETA: 9s - loss: 0.1714 - binary_accuracy: 0.9283 - dice_coef: 0.831 - ETA: 9s - loss: 0.1724 - binary_accuracy: 0.9269 - dice_coef: 0.830 - ETA: 9s - loss: 0.1715 - binary_accuracy: 0.9271 - dice_coef: 0.831 - ETA: 9s - loss: 0.1724 - binary_accuracy: 0.9270 - dice_coef: 0.830 - ETA: 9s - loss: 0.1720 - binary_accuracy: 0.9270 - dice_coef: 0.830 - ETA: 9s - loss: 0.1725 - binary_accuracy: 0.9268 - dice_coef: 0.830 - ETA: 9s - loss: 0.1726 - binary_accuracy: 0.9274 - dice_coef: 0.830 - ETA: 8s - loss: 0.1726 - binary_accuracy: 0.9275 - dice_coef: 0.830 - ETA: 8s - loss: 0.1725 - binary_accuracy: 0.9275 - dice_coef: 0.830 - ETA: 8s - loss: 0.1723 - binary_accuracy: 0.9281 - dice_coef: 0.830 - ETA: 8s - loss: 0.1721 - binary_accuracy: 0.9282 - dice_coef: 0.830 - ETA: 8s - loss: 0.1722 - binary_accuracy: 0.9286 - dice_coef: 0.830 - ETA: 8s - loss: 0.1725 - binary_accuracy: 0.9284 - dice_coef: 0.830 - ETA: 8s - loss: 0.1723 - binary_accuracy: 0.9285 - dice_coef: 0.830 - ETA: 7s - loss: 0.1717 - binary_accuracy: 0.9287 - dice_coef: 0.831 - ETA: 7s - loss: 0.1724 - binary_accuracy: 0.9290 - dice_coef: 0.830 - ETA: 7s - loss: 0.1724 - binary_accuracy: 0.9291 - dice_coef: 0.830 - ETA: 7s - loss: 0.1728 - binary_accuracy: 0.9291 - dice_coef: 0.830 - ETA: 7s - loss: 0.1728 - binary_accuracy: 0.9287 - dice_coef: 0.830 - ETA: 7s - loss: 0.1735 - binary_accuracy: 0.9286 - dice_coef: 0.829 - ETA: 7s - loss: 0.1739 - binary_accuracy: 0.9284 - dice_coef: 0.828 - ETA: 7s - loss: 0.1742 - binary_accuracy: 0.9281 - dice_coef: 0.828 - ETA: 6s - loss: 0.1744 - binary_accuracy: 0.9282 - dice_coef: 0.828 - ETA: 6s - loss: 0.1745 - binary_accuracy: 0.9281 - dice_coef: 0.828 - ETA: 6s - loss: 0.1743 - binary_accuracy: 0.9280 - dice_coef: 0.828 - ETA: 6s - loss: 0.1746 - binary_accuracy: 0.9281 - dice_coef: 0.828 - ETA: 6s - loss: 0.1749 - binary_accuracy: 0.9284 - dice_coef: 0.827 - ETA: 6s - loss: 0.1753 - binary_accuracy: 0.9286 - dice_coef: 0.827 - ETA: 6s - loss: 0.1760 - binary_accuracy: 0.9282 - dice_coef: 0.826 - ETA: 6s - loss: 0.1767 - binary_accuracy: 0.9281 - dice_coef: 0.826 - ETA: 5s - loss: 0.1766 - binary_accuracy: 0.9284 - dice_coef: 0.826 - ETA: 5s - loss: 0.1763 - binary_accu ...
#
# Epoch 00009: val_loss did not improve
# Epoch 10/15
# 100/100 [==============================] - ETA: 13s - loss: 0.1809 - binary_accuracy: 0.9138 - dice_coef: 0.82 - ETA: 13s - loss: 0.1863 - binary_accuracy: 0.9228 - dice_coef: 0.81 - ETA: 13s - loss: 0.1769 - binary_accuracy: 0.9256 - dice_coef: 0.82 - ETA: 12s - loss: 0.1818 - binary_accuracy: 0.9296 - dice_coef: 0.82 - ETA: 12s - loss: 0.1781 - binary_accuracy: 0.9300 - dice_coef: 0.82 - ETA: 12s - loss: 0.1843 - binary_accuracy: 0.9322 - dice_coef: 0.81 - ETA: 12s - loss: 0.1816 - binary_accuracy: 0.9322 - dice_coef: 0.82 - ETA: 12s - loss: 0.1828 - binary_accuracy: 0.9310 - dice_coef: 0.81 - ETA: 12s - loss: 0.1848 - binary_accuracy: 0.9298 - dice_coef: 0.81 - ETA: 12s - loss: 0.1836 - binary_accuracy: 0.9294 - dice_coef: 0.81 - ETA: 12s - loss: 0.1822 - binary_accuracy: 0.9290 - dice_coef: 0.82 - ETA: 11s - loss: 0.1795 - binary_accuracy: 0.9299 - dice_coef: 0.82 - ETA: 11s - loss: 0.1777 - binary_accuracy: 0.9325 - dice_coef: 0.82 - ETA: 11s - loss: 0.1761 - binary_accuracy: 0.9328 - dice_coef: 0.82 - ETA: 11s - loss: 0.1748 - binary_accuracy: 0.9331 - dice_coef: 0.82 - ETA: 11s - loss: 0.1755 - binary_accuracy: 0.9323 - dice_coef: 0.82 - ETA: 11s - loss: 0.1737 - binary_accuracy: 0.9318 - dice_coef: 0.82 - ETA: 11s - loss: 0.1741 - binary_accuracy: 0.9317 - dice_coef: 0.82 - ETA: 10s - loss: 0.1771 - binary_accuracy: 0.9323 - dice_coef: 0.82 - ETA: 10s - loss: 0.1756 - binary_accuracy: 0.9325 - dice_coef: 0.82 - ETA: 10s - loss: 0.1768 - binary_accuracy: 0.9327 - dice_coef: 0.82 - ETA: 10s - loss: 0.1762 - binary_accuracy: 0.9327 - dice_coef: 0.82 - ETA: 10s - loss: 0.1767 - binary_accuracy: 0.9325 - dice_coef: 0.82 - ETA: 10s - loss: 0.1768 - binary_accuracy: 0.9326 - dice_coef: 0.82 - ETA: 10s - loss: 0.1796 - binary_accuracy: 0.9332 - dice_coef: 0.82 - ETA: 10s - loss: 0.1819 - binary_accuracy: 0.9328 - dice_coef: 0.82 - ETA: 9s - loss: 0.1810 - binary_accuracy: 0.9328 - dice_coef: 0.8216 - ETA: 9s - loss: 0.1802 - binary_accuracy: 0.9335 - dice_coef: 0.822 - ETA: 9s - loss: 0.1795 - binary_accuracy: 0.9328 - dice_coef: 0.823 - ETA: 9s - loss: 0.1799 - binary_accuracy: 0.9314 - dice_coef: 0.822 - ETA: 9s - loss: 0.1812 - binary_accuracy: 0.9309 - dice_coef: 0.821 - ETA: 9s - loss: 0.1811 - binary_accuracy: 0.9298 - dice_coef: 0.821 - ETA: 9s - loss: 0.1806 - binary_accuracy: 0.9301 - dice_coef: 0.821 - ETA: 8s - loss: 0.1805 - binary_accuracy: 0.9298 - dice_coef: 0.822 - ETA: 8s - loss: 0.1801 - binary_accuracy: 0.9301 - dice_coef: 0.822 - ETA: 8s - loss: 0.1794 - binary_accuracy: 0.9296 - dice_coef: 0.823 - ETA: 8s - loss: 0.1795 - binary_accuracy: 0.9293 - dice_coef: 0.823 - ETA: 8s - loss: 0.1797 - binary_accuracy: 0.9288 - dice_coef: 0.822 - ETA: 8s - loss: 0.1801 - binary_accuracy: 0.9292 - dice_coef: 0.822 - ETA: 8s - loss: 0.1796 - binary_accuracy: 0.9293 - dice_coef: 0.822 - ETA: 8s - loss: 0.1792 - binary_accuracy: 0.9294 - dice_coef: 0.823 - ETA: 7s - loss: 0.1799 - binary_accuracy: 0.9289 - dice_coef: 0.822 - ETA: 7s - loss: 0.1801 - binary_accuracy: 0.9290 - dice_coef: 0.822 - ETA: 7s - loss: 0.1793 - binary_accuracy: 0.9292 - dice_coef: 0.823 - ETA: 7s - loss: 0.1791 - binary_accuracy: 0.9290 - dice_coef: 0.823 - ETA: 7s - loss: 0.1793 - binary_accuracy: 0.9285 - dice_coef: 0.823 - ETA: 7s - loss: 0.1791 - binary_accuracy: 0.9286 - dice_coef: 0.823 - ETA: 7s - loss: 0.1791 - binary_accuracy: 0.9285 - dice_coef: 0.823 - ETA: 6s - loss: 0.1789 - binary_accuracy: 0.9287 - dice_coef: 0.823 - ETA: 6s - loss: 0.1789 - binary_accuracy: 0.9288 - dice_coef: 0.823 - ETA: 6s - loss: 0.1785 - binary_accuracy: 0.9286 - dice_coef: 0.823 - ETA: 6s - loss: 0.1784 - binary_accuracy: 0.9286 - dice_coef: 0.824 - ETA: 6s - loss: 0.1783 - binary_accuracy: 0.9285 - dice_coef: 0.824 - ETA: 6s - loss: 0.1778 - binary_accuracy: 0.9287 - dice_coef: 0.824 - ETA: 6s - loss: 0.1778 - binary_accuracy: 0.9284 - dice_coef: 0.824 - ETA: 5s - loss: 0.1776 - binary_accuracy: 0.9286 - dice_coef: 0.824 - ETA: 5s - loss: 0.1778 - binary_accu ...
#
# Epoch 00010: val_loss improved from 0.16880 to 0.16223, saving model to ./keras_DRIVE_Binary.model
# Epoch 11/15
# ...
#
# Epoch 00012: val_loss did not improve
# Epoch 13/15
# 100/100 [==============================] - ETA: 13s - loss: 0.1729 - binary_accuracy: 0.9240 - dice_coef: 0.82 - ETA: 13s - loss: 0.1834 - binary_accuracy: 0.9206 - dice_coef: 0.81 - ETA: 13s - loss: 0.1725 - binary_accuracy: 0.9304 - dice_coef: 0.82 - ETA: 13s - loss: 0.1737 - binary_accuracy: 0.9330 - dice_coef: 0.82 - ETA: 13s - loss: 0.1723 - binary_accuracy: 0.9309 - dice_coef: 0.82 - ETA: 12s - loss: 0.1709 - binary_accuracy: 0.9284 - dice_coef: 0.83 - ETA: 12s - loss: 0.1676 - binary_accuracy: 0.9280 - dice_coef: 0.83 - ETA: 12s - loss: 0.1676 - binary_accuracy: 0.9289 - dice_coef: 0.83 - ETA: 12s - loss: 0.1674 - binary_accuracy: 0.9274 - dice_coef: 0.83 - ETA: 12s - loss: 0.1720 - binary_accuracy: 0.9280 - dice_coef: 0.82 - ETA: 12s - loss: 0.1710 - binary_accuracy: 0.9271 - dice_coef: 0.83 - ETA: 11s - loss: 0.1714 - binary_accuracy: 0.9261 - dice_coef: 0.83 - ETA: 11s - loss: 0.1690 - binary_accuracy: 0.9258 - dice_coef: 0.83 - ETA: 11s - loss: 0.1708 - binary_accuracy: 0.9272 - dice_coef: 0.83 - ETA: 11s - loss: 0.1681 - binary_accuracy: 0.9283 - dice_coef: 0.83 - ETA: 11s - loss: 0.1694 - binary_accuracy: 0.9283 - dice_coef: 0.83 - ETA: 11s - loss: 0.1684 - binary_accuracy: 0.9292 - dice_coef: 0.83 - ETA: 11s - loss: 0.1695 - binary_accuracy: 0.9282 - dice_coef: 0.83 - ETA: 10s - loss: 0.1702 - binary_accuracy: 0.9272 - dice_coef: 0.83 - ETA: 10s - loss: 0.1693 - binary_accuracy: 0.9269 - dice_coef: 0.83 - ETA: 10s - loss: 0.1689 - binary_accuracy: 0.9267 - dice_coef: 0.83 - ETA: 10s - loss: 0.1688 - binary_accuracy: 0.9273 - dice_coef: 0.83 - ETA: 10s - loss: 0.1689 - binary_accuracy: 0.9266 - dice_coef: 0.83 - ETA: 10s - loss: 0.1686 - binary_accuracy: 0.9278 - dice_coef: 0.83 - ETA: 10s - loss: 0.1678 - binary_accuracy: 0.9272 - dice_coef: 0.83 - ETA: 9s - loss: 0.1687 - binary_accuracy: 0.9267 - dice_coef: 0.8328 - ETA: 9s - loss: 0.1678 - binary_accuracy: 0.9261 - dice_coef: 0.833 - ETA: 9s - loss: 0.1685 - binary_accuracy: 0.9261 - dice_coef: 0.832 - ETA: 9s - loss: 0.1689 - binary_accuracy: 0.9260 - dice_coef: 0.832 - ETA: 9s - loss: 0.1686 - binary_accuracy: 0.9272 - dice_coef: 0.832 - ETA: 9s - loss: 0.1682 - binary_accuracy: 0.9273 - dice_coef: 0.833 - ETA: 9s - loss: 0.1674 - binary_accuracy: 0.9279 - dice_coef: 0.834 - ETA: 9s - loss: 0.1664 - binary_accuracy: 0.9283 - dice_coef: 0.835 - ETA: 8s - loss: 0.1663 - binary_accuracy: 0.9288 - dice_coef: 0.835 - ETA: 8s - loss: 0.1667 - binary_accuracy: 0.9283 - dice_coef: 0.834 - ETA: 8s - loss: 0.1666 - binary_accuracy: 0.9279 - dice_coef: 0.834 - ETA: 8s - loss: 0.1671 - binary_accuracy: 0.9282 - dice_coef: 0.834 - ETA: 8s - loss: 0.1679 - binary_accuracy: 0.9281 - dice_coef: 0.833 - ETA: 8s - loss: 0.1679 - binary_accuracy: 0.9280 - dice_coef: 0.833 - ETA: 8s - loss: 0.1686 - binary_accuracy: 0.9282 - dice_coef: 0.832 - ETA: 7s - loss: 0.1692 - binary_accuracy: 0.9282 - dice_coef: 0.832 - ETA: 7s - loss: 0.1695 - binary_accuracy: 0.9282 - dice_coef: 0.831 - ETA: 7s - loss: 0.1695 - binary_accuracy: 0.9281 - dice_coef: 0.831 - ETA: 7s - loss: 0.1695 - binary_accuracy: 0.9285 - dice_coef: 0.832 - ETA: 7s - loss: 0.1690 - binary_accuracy: 0.9293 - dice_coef: 0.832 - ETA: 7s - loss: 0.1695 - binary_accuracy: 0.9294 - dice_coef: 0.832 - ETA: 7s - loss: 0.1699 - binary_accuracy: 0.9290 - dice_coef: 0.831 - ETA: 6s - loss: 0.1696 - binary_accuracy: 0.9293 - dice_coef: 0.831 - ETA: 6s - loss: 0.1696 - binary_accuracy: 0.9296 - dice_coef: 0.831 - ETA: 6s - loss: 0.1694 - binary_accuracy: 0.9297 - dice_coef: 0.832 - ETA: 6s - loss: 0.1686 - binary_accuracy: 0.9301 - dice_coef: 0.832 - ETA: 6s - loss: 0.1692 - binary_accuracy: 0.9303 - dice_coef: 0.832 - ETA: 6s - loss: 0.1687 - binary_accuracy: 0.9308 - dice_coef: 0.832 - ETA: 6s - loss: 0.1691 - binary_accuracy: 0.9303 - dice_coef: 0.832 - ETA: 6s - loss: 0.1690 - binary_accuracy: 0.9302 - dice_coef: 0.832 - ETA: 5s - loss: 0.1689 - binary_accuracy: 0.9304 - dice_coef: 0.832 - ETA: 5s - loss: 0.1685 - binary_accu ...
#
# Epoch 00013: val_loss did not improve
# Epoch 14/15
# 100/100 [==============================] - ETA: 13s - loss: 0.1424 - binary_accuracy: 0.9508 - dice_coef: 0.85 - ETA: 13s - loss: 0.1497 - binary_accuracy: 0.9349 - dice_coef: 0.85 - ETA: 13s - loss: 0.1534 - binary_accuracy: 0.9266 - dice_coef: 0.84 - ETA: 12s - loss: 0.1530 - binary_accuracy: 0.9300 - dice_coef: 0.84 - ETA: 12s - loss: 0.1530 - binary_accuracy: 0.9295 - dice_coef: 0.84 - ETA: 13s - loss: 0.1564 - binary_accuracy: 0.9311 - dice_coef: 0.84 - ETA: 12s - loss: 0.1696 - binary_accuracy: 0.9316 - dice_coef: 0.83 - ETA: 12s - loss: 0.1670 - binary_accuracy: 0.9297 - dice_coef: 0.83 - ETA: 12s - loss: 0.1665 - binary_accuracy: 0.9290 - dice_coef: 0.83 - ETA: 12s - loss: 0.1657 - binary_accuracy: 0.9276 - dice_coef: 0.83 - ETA: 12s - loss: 0.1625 - binary_accuracy: 0.9288 - dice_coef: 0.83 - ETA: 12s - loss: 0.1647 - binary_accuracy: 0.9260 - dice_coef: 0.83 - ETA: 11s - loss: 0.1640 - binary_accuracy: 0.9264 - dice_coef: 0.83 - ETA: 11s - loss: 0.1664 - binary_accuracy: 0.9277 - dice_coef: 0.83 - ETA: 11s - loss: 0.1691 - binary_accuracy: 0.9273 - dice_coef: 0.83 - ETA: 11s - loss: 0.1698 - binary_accuracy: 0.9264 - dice_coef: 0.83 - ETA: 11s - loss: 0.1705 - binary_accuracy: 0.9268 - dice_coef: 0.83 - ETA: 11s - loss: 0.1696 - binary_accuracy: 0.9279 - dice_coef: 0.83 - ETA: 11s - loss: 0.1712 - binary_accuracy: 0.9285 - dice_coef: 0.83 - ETA: 10s - loss: 0.1707 - binary_accuracy: 0.9293 - dice_coef: 0.83 - ETA: 10s - loss: 0.1702 - binary_accuracy: 0.9301 - dice_coef: 0.83 - ETA: 10s - loss: 0.1697 - binary_accuracy: 0.9298 - dice_coef: 0.83 - ETA: 10s - loss: 0.1691 - binary_accuracy: 0.9289 - dice_coef: 0.83 - ETA: 10s - loss: 0.1690 - binary_accuracy: 0.9280 - dice_coef: 0.83 - ETA: 10s - loss: 0.1694 - binary_accuracy: 0.9276 - dice_coef: 0.83 - ETA: 10s - loss: 0.1700 - binary_accuracy: 0.9276 - dice_coef: 0.83 - ETA: 10s - loss: 0.1705 - binary_accuracy: 0.9282 - dice_coef: 0.83 - ETA: 9s - loss: 0.1705 - binary_accuracy: 0.9286 - dice_coef: 0.8308 - ETA: 9s - loss: 0.1705 - binary_accuracy: 0.9288 - dice_coef: 0.830 - ETA: 9s - loss: 0.1710 - binary_accuracy: 0.9284 - dice_coef: 0.830 - ETA: 9s - loss: 0.1721 - binary_accuracy: 0.9287 - dice_coef: 0.829 - ETA: 9s - loss: 0.1727 - binary_accuracy: 0.9290 - dice_coef: 0.828 - ETA: 9s - loss: 0.1721 - binary_accuracy: 0.9289 - dice_coef: 0.829 - ETA: 9s - loss: 0.1712 - binary_accuracy: 0.9292 - dice_coef: 0.830 - ETA: 8s - loss: 0.1708 - binary_accuracy: 0.9291 - dice_coef: 0.830 - ETA: 8s - loss: 0.1716 - binary_accuracy: 0.9292 - dice_coef: 0.829 - ETA: 8s - loss: 0.1718 - binary_accuracy: 0.9288 - dice_coef: 0.829 - ETA: 8s - loss: 0.1718 - binary_accuracy: 0.9293 - dice_coef: 0.829 - ETA: 8s - loss: 0.1710 - binary_accuracy: 0.9294 - dice_coef: 0.830 - ETA: 8s - loss: 0.1716 - binary_accuracy: 0.9298 - dice_coef: 0.829 - ETA: 8s - loss: 0.1709 - binary_accuracy: 0.9301 - dice_coef: 0.830 - ETA: 7s - loss: 0.1709 - binary_accuracy: 0.9302 - dice_coef: 0.830 - ETA: 7s - loss: 0.1713 - binary_accuracy: 0.9302 - dice_coef: 0.830 - ETA: 7s - loss: 0.1720 - binary_accuracy: 0.9306 - dice_coef: 0.829 - ETA: 7s - loss: 0.1720 - binary_accuracy: 0.9303 - dice_coef: 0.829 - ETA: 7s - loss: 0.1714 - binary_accuracy: 0.9300 - dice_coef: 0.829 - ETA: 7s - loss: 0.1714 - binary_accuracy: 0.9300 - dice_coef: 0.829 - ETA: 7s - loss: 0.1717 - binary_accuracy: 0.9303 - dice_coef: 0.829 - ETA: 6s - loss: 0.1718 - binary_accuracy: 0.9300 - dice_coef: 0.829 - ETA: 6s - loss: 0.1725 - binary_accuracy: 0.9303 - dice_coef: 0.828 - ETA: 6s - loss: 0.1730 - binary_accuracy: 0.9302 - dice_coef: 0.828 - ETA: 6s - loss: 0.1733 - binary_accuracy: 0.9299 - dice_coef: 0.828 - ETA: 6s - loss: 0.1729 - binary_accuracy: 0.9302 - dice_coef: 0.828 - ETA: 6s - loss: 0.1724 - binary_accuracy: 0.9302 - dice_coef: 0.828 - ETA: 6s - loss: 0.1725 - binary_accuracy: 0.9301 - dice_coef: 0.828 - ETA: 6s - loss: 0.1718 - binary_accuracy: 0.9307 - dice_coef: 0.829 - ETA: 5s - loss: 0.1713 - binary_accu ...
#
# Epoch 00014: val_loss improved from 0.16223 to 0.16086, saving model to ./keras_DRIVE_Binary.model
# Epoch 15/15
# 100/100 [==============================] - ETA: 13s - loss: 0.1678 - binary_accuracy: 0.9434 - dice_coef: 0.83 - ETA: 13s - loss: 0.1763 - binary_accuracy: 0.9446 - dice_coef: 0.82 - ETA: 13s - loss: 0.1770 - binary_accuracy: 0.9365 - dice_coef: 0.82 - ETA: 13s - loss: 0.1743 - binary_accuracy: 0.9330 - dice_coef: 0.82 - ETA: 13s - loss: 0.1720 - binary_accuracy: 0.9312 - dice_coef: 0.82 - ETA: 12s - loss: 0.1711 - binary_accuracy: 0.9309 - dice_coef: 0.83 - ETA: 12s - loss: 0.1683 - binary_accuracy: 0.9355 - dice_coef: 0.83 - ETA: 12s - loss: 0.1694 - binary_accuracy: 0.9350 - dice_coef: 0.83 - ETA: 12s - loss: 0.1679 - binary_accuracy: 0.9355 - dice_coef: 0.83 - ETA: 12s - loss: 0.1670 - binary_accuracy: 0.9365 - dice_coef: 0.83 - ETA: 12s - loss: 0.1688 - binary_accuracy: 0.9375 - dice_coef: 0.83 - ETA: 11s - loss: 0.1684 - binary_accuracy: 0.9352 - dice_coef: 0.83 - ETA: 11s - loss: 0.1682 - binary_accuracy: 0.9325 - dice_coef: 0.83 - ETA: 11s - loss: 0.1683 - binary_accuracy: 0.9309 - dice_coef: 0.83 - ETA: 11s - loss: 0.1675 - binary_accuracy: 0.9320 - dice_coef: 0.83 - ETA: 11s - loss: 0.1679 - binary_accuracy: 0.9306 - dice_coef: 0.83 - ETA: 11s - loss: 0.1686 - binary_accuracy: 0.9300 - dice_coef: 0.83 - ETA: 11s - loss: 0.1682 - binary_accuracy: 0.9292 - dice_coef: 0.83 - ETA: 11s - loss: 0.1672 - binary_accuracy: 0.9297 - dice_coef: 0.83 - ETA: 10s - loss: 0.1674 - binary_accuracy: 0.9286 - dice_coef: 0.83 - ETA: 10s - loss: 0.1681 - binary_accuracy: 0.9282 - dice_coef: 0.83 - ETA: 10s - loss: 0.1682 - binary_accuracy: 0.9285 - dice_coef: 0.83 - ETA: 10s - loss: 0.1673 - binary_accuracy: 0.9287 - dice_coef: 0.83 - ETA: 10s - loss: 0.1683 - binary_accuracy: 0.9277 - dice_coef: 0.83 - ETA: 10s - loss: 0.1696 - binary_accuracy: 0.9280 - dice_coef: 0.83 - ETA: 10s - loss: 0.1708 - binary_accuracy: 0.9267 - dice_coef: 0.83 - ETA: 9s - loss: 0.1708 - binary_accuracy: 0.9260 - dice_coef: 0.8305 - ETA: 9s - loss: 0.1711 - binary_accuracy: 0.9262 - dice_coef: 0.830 - ETA: 9s - loss: 0.1719 - binary_accuracy: 0.9253 - dice_coef: 0.829 - ETA: 9s - loss: 0.1714 - binary_accuracy: 0.9244 - dice_coef: 0.829 - ETA: 9s - loss: 0.1712 - binary_accuracy: 0.9246 - dice_coef: 0.830 - ETA: 9s - loss: 0.1704 - binary_accuracy: 0.9252 - dice_coef: 0.830 - ETA: 9s - loss: 0.1711 - binary_accuracy: 0.9246 - dice_coef: 0.830 - ETA: 9s - loss: 0.1703 - binary_accuracy: 0.9254 - dice_coef: 0.830 - ETA: 8s - loss: 0.1695 - binary_accuracy: 0.9256 - dice_coef: 0.831 - ETA: 8s - loss: 0.1699 - binary_accuracy: 0.9253 - dice_coef: 0.831 - ETA: 8s - loss: 0.1694 - binary_accuracy: 0.9255 - dice_coef: 0.831 - ETA: 8s - loss: 0.1700 - binary_accuracy: 0.9256 - dice_coef: 0.831 - ETA: 8s - loss: 0.1693 - binary_accuracy: 0.9260 - dice_coef: 0.831 - ETA: 8s - loss: 0.1686 - binary_accuracy: 0.9262 - dice_coef: 0.832 - ETA: 8s - loss: 0.1687 - binary_accuracy: 0.9266 - dice_coef: 0.832 - ETA: 7s - loss: 0.1702 - binary_accuracy: 0.9259 - dice_coef: 0.831 - ETA: 7s - loss: 0.1698 - binary_accuracy: 0.9261 - dice_coef: 0.831 - ETA: 7s - loss: 0.1695 - binary_accuracy: 0.9262 - dice_coef: 0.831 - ETA: 7s - loss: 0.1694 - binary_accuracy: 0.9265 - dice_coef: 0.831 - ETA: 7s - loss: 0.1699 - binary_accuracy: 0.9262 - dice_coef: 0.831 - ETA: 7s - loss: 0.1702 - binary_accuracy: 0.9262 - dice_coef: 0.831 - ETA: 7s - loss: 0.1704 - binary_accuracy: 0.9263 - dice_coef: 0.830 - ETA: 6s - loss: 0.1709 - binary_accuracy: 0.9262 - dice_coef: 0.830 - ETA: 6s - loss: 0.1706 - binary_accuracy: 0.9262 - dice_coef: 0.830 - ETA: 6s - loss: 0.1707 - binary_accuracy: 0.9262 - dice_coef: 0.830 - ETA: 6s - loss: 0.1701 - binary_accuracy: 0.9268 - dice_coef: 0.831 - ETA: 6s - loss: 0.1699 - binary_accuracy: 0.9269 - dice_coef: 0.831 - ETA: 6s - loss: 0.1696 - binary_accuracy: 0.9273 - dice_coef: 0.831 - ETA: 6s - loss: 0.1700 - binary_accuracy: 0.9273 - dice_coef: 0.831 - ETA: 5s - loss: 0.1701 - binary_accuracy: 0.9273 - dice_coef: 0.831 - ETA: 5s - loss: 0.1697 - binary_accu ...
#
# Epoch 00015: val_loss did not improve
# [INFO] Finishing...

# %%
#from perception.infers.segmention_infer_prob import SegmentionInfer
from perception.infers.segmention_infer import SegmentionInferprob,SegmentionInfer,SegmentionInferbinary,SegmentionInferbinaryprob,SegmentionInferMulticlass

#from perception.infers.segmention_infer_STARE import SegmentionInfer

from perception.metric.segmention_metric import *
from configs.utils.config_utils import process_config


repredict=True

def main_test():
    print('[INFO] Reading Configs...')
    config = None

    try:
        config = process_config('./configs/segmention_config.json')
        config.G = 0.80
        config.R = 0.20
        config.B = 0.0   
        config.color_space = 'RGB'
        #config.color_space = 'HSV'
        config.multi_proportion =1        
        #config.seg_num = 4
        #config.test_img_path = ".\\experiments\\VesselNet\\dataset\\DRIVE\\validate\\bright\\"
        #config.test_groundtruth_path = ".\\experiments\\VesselNet\\dataset\\DRIVE\\validate\\bright_gt\\"
        #config.test_img_path = ".\\experiments\\VesselNet\\dataset\\DRIVE\\validate\\dark\\"
        #config.test_groundtruth_path = ".\\experiments\\VesselNet\\dataset\\DRIVE\\validate\\dark_gt\\"
        #config.test_prob_path == '.\\experiments\\VesselNet\\test\\probmap\\'
        #config.test_img_path = ".\\experiments\\VesselNet\\dataset\\DRIVE\\train\\semi_validate_img\\"
        config.test_groundtruth_path = ".\\experiments\\VesselNet\\dataset\\DRIVE\\validate\\origin\\"
        if config.color_space == 'RGB':
            config.test_result_path = ".\\experiments\\VesselNet\\dataset\\DRIVE\\validate\\result_demo_RGB\\"
        elif config.color_space == 'HSV':
            config.test_result_path = ".\\experiments\\VesselNet\\dataset\\DRIVE\\validate\\result_demo_HSV\\"
        elif config.color_space == 'LAB':
            config.test_result_path = ".\\experiments\\VesselNet\\dataset\\DRIVE\\validate\\result_demo_LAB\\"
            
        config.patch_height =128
        config.patch_width = 128  
        config.stride_width = 32
        config.stride_height = 32       

            
        if config.multi_proportion :
            config.test_result_path = ".\\experiments\\VesselNet\\dataset\\DRIVE\\validate\\result_demo_{}_{}G_{}R_{}B\\".format(config.patch_height,config.G,config.R,config.B)
        if not os.path.exists(config.test_result_path):
            os.mkdir(config.test_result_path)
        #config.test_img_path = './experiments/VesselNet/dataset/DRIVE/train/origin/'
       # config.test_gt_path = './experiments/VesselNet/dataset/DRIVE/train/img_gt/'
        
        #config = process_config('./configs/segmention_config_CHASEDB1.json')
        #config.train_img_path = ".\\experiments\\VesselNet\\dataset\\CHASEDB1\\train\\"
       # config.train_groundtruth_path =".\\experiments\\VesselNet\\dataset\\train\\"
        #config.val_img_path = ".\\experiments\\VesselNet\\dataset\\CHASEDB1\\validate\\"
        #config.val_groundtruth_path = ".\\experiments\\VesselNet\\dataset\\validate\\groundtruth\\"
      
        #config.test_img_path =".\\experiments\\VesselNet\\dataset\\HRF\\validate\\images\\"
       # config.test_gt_path = '.\\experiments\\VesselNet\\dataset\\HRF\\validate\\gt\\'
        #config.test_result_path='.\\experiments\\VesselNet\\dataset\\HRF\\result\\'
       #config.test_datatype='jpg'
       # config.test_gt_datatype ='tif'
        #config = process_config('./configs/segmention_config_STARE.json')
        #config.test_img_path =".\\experiments\\VesselNet\\dataset\\STARE\\img_bmp\\"
        #config.test_gt_path = '.\\experiments\\VesselNet\\dataset\\STARE\\gt_bmp\\'
        #config.test_result_path='.\\experiments\\VesselNet\\dataset\\STARE\\result\\'
        #config.test_datatype='bmp'
        #config.test_gt_datatype ='bmp'

        #config.test_prob_path = '.\\experiments\\VesselNet\\test\\probmap1\\'
        print(config)
    except Exception as e:
        print('[Exception] Config Error, %s' % e)
        exit(0)

    if repredict==True:
        #config.color_space = 'RGB'
        #config.color_space = 'HSV'
        config.multi_proportion = 1
       # print('[INFO] Predicting...')
        #infer = SegmentionInferprob(config)
        infer = SegmentionInferbinary(config)
        #infer = SegmentionInferbinaryprob(config)
        #infer = SegmentionInfer(config)
        #infer = SegmentionInferMulticlass(config)
        infer.predict()

    print('[INFO] Metric results...')
    gtlist=fileList(config.test_gt_path,'*'+config.test_gt_datatype)
    problist=fileList(config.test_result_path,'*.bmp')
    #print(gtlist)
   # print()
    modelName=['DenseNet-Unet']
    #drawCurve(gtlist,[problist],modelName,'DRIVE',config.checkpoint)

    print('[INFO] Fininshed...')


if __name__ == '__main__':
    main_test()
# Out:
# [INFO] Reading Configs...
# B: 0.0
# G: 0.8
# R: 0.2
# batch_size: 25
# checkpoint: ./experiments\VesselNet\checkpoint/
# color_space: RGB
# epochs: 10
# exp_name: VesselNet
# hdf5_path: ./experiments\VesselNet\hdf5/
# height: 584
# multi_proportion: 1
# patch_height: 128
# patch_width: 128
# seg_num: 1
# stride_height: 32
# stride_width: 32
# subsample: 500
# test_datatype: tif
# test_groundtruth_path: .\experiments\VesselNet\dataset\DRIVE\validate\origin\
# test_gt_datatype: tif
# test_gt_path: ./experiments\VesselNet\test/groundtruth/
# test_img_path: ./experiments\VesselNet\test/origin/
# test_result_path: .\experiments\VesselNet\dataset\DRIVE\validate\result_demo_128_0.8G_0.2R_0.0B\
# total_train: 40
# total_val: 20
# train_datatype: tif
# train_groundtruth_path: ./experiments\VesselNet\dataset/train/groundtruth/
# train_gt_datatype: tif
# train_img_path: ./experiments\VesselNet\dataset/train/origin/
# val_datatype: tif
# val_groundtruth_path: ./experiments\VesselNet\dataset/validate/groundtruth/
# val_gt_datatype: tif
# val_img_path: ./experiments\VesselNet\dataset/validate/origin/
# width: 565
#
# loading_orig_weights
# 20
# Color Space: RGB
# G_ratio:0.8 R_ratio:0.2 B_ratio:0.0
# [Info] Analyze filename... 01_test
# new full images shape:
# (1, 608, 576, 1)
# 240/240 [==============================] - ETA: 11 - ETA: 5 - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - 3s 12ms/step
# N_patches_h: 16
# N_patches_w: 15
# N_patches_img: 240
# According to the dimension inserted, there are 1 full images (of 608x576 each)
# 240 240
# using avg
# Color Space: RGB
# G_ratio:0.8 R_ratio:0.2 B_ratio:0.0
# [Info] Analyze filename... 02_test
# new full images shape:
# (1, 608, 576, 1)
# 240/240 [==============================] - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - 1s 5ms/step
# N_patches_h: 16
# N_patches_w: 15
# N_patches_img: 240
# According to the dimension inserted, there are 1 full images (of 608x576 each)
# 240 240
# using avg
# Color Space: RGB
# G_ratio:0.8 R_ratio:0.2 B_ratio:0.0
# [Info] Analyze filename... 03_test
# new full images shape:
# (1, 608, 576, 1)
# 240/240 [==============================] - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - 1s 5ms/step
# N_patches_h: 16
# N_patches_w: 15
# N_patches_img: 240
# According to the dimension inserted, there are 1 full images (of 608x576 each)
# 240 240
# using avg
# Color Space: RGB
# G_ratio:0.8 R_ratio:0.2 B_ratio:0.0
# [Info] Analyze filename... 04_test
# new full images shape:
# (1, 608, 576, 1)
# 240/240 [==============================] - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - 1s 5ms/step
# N_patches_h: 16
# N_patches_w: 15
# N_patches_img: 240
# According to the dimension inserted, there are 1 full images (of 608x576 each)
# 240 240
# using avg
# Color Space: RGB
# G_ratio:0.8 R_ratio:0.2 B_ratio:0.0
# [Info] Analyze filename... 05_test
# new full images shape:
# (1, 608, 576, 1)
# 240/240 [==============================] - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - 1s 5ms/step
# N_patches_h: 16
# N_patches_w: 15
# N_patches_img: 240
# According to the dimension inserted, there are 1 full images (of 608x576 each)
# 240 240
# using avg
# Color Space: RGB
# G_ratio:0.8 R_ratio:0.2 B_ratio:0.0
# [Info] Analyze filename... 06_test
# new full images shape:
# (1, 608, 576, 1)
# 240/240 [==============================] - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - 1s 5ms/step
# N_patches_h: 16
# N_patches_w: 15
# N_patches_img: 240
# According to the dimension inserted, there are 1 full images (of 608x576 each)
# 240 240
# using avg
# Color Space: RGB
# G_ratio:0.8 R_ratio:0.2 B_ratio:0.0
# [Info] Analyze filename... 07_test
# new full images shape:
# (1, 608, 576, 1)
# 240/240 [==============================] - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - 1s 5ms/step
# N_patches_h: 16
# N_patches_w: 15
# N_patches_img: 240
# According to the dimension inserted, there are 1 full images (of 608x576 each)
# 240 240
# using avg
# Color Space: RGB
# G_ratio:0.8 R_ratio:0.2 B_ratio:0.0
# [Info] Analyze filename... 08_test
# new full images shape:
# (1, 608, 576, 1)
# 240/240 [==============================] - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - 1s 5ms/step
# N_patches_h: 16
# N_patches_w: 15
# N_patches_img: 240
# According to the dimension inserted, there are 1 full images (of 608x576 each)
# 240 240
# using avg
# Color Space: RGB
# G_ratio:0.8 R_ratio:0.2 B_ratio:0.0
# [Info] Analyze filename... 09_test
# new full images shape:
# (1, 608, 576, 1)
# 240/240 [==============================] - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - 1s 5ms/step
# N_patches_h: 16
# N_patches_w: 15
# N_patches_img: 240
# According to the dimension inserted, there are 1 full images (of 608x576 each)
# 240 240
# using avg
# Color Space: RGB
# G_ratio:0.8 R_ratio:0.2 B_ratio:0.0
# [Info] Analyze filename... 10_test
# new full images shape:
# (1, 608, 576, 1)
# 240/240 [==============================] - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - 1s 5ms/step
# N_patches_h: 16
# N_patches_w: 15
# N_patches_img: 240
# According to the dimension inserted, there are 1 full images (of 608x576 each)
# 240 240
# using avg
# Color Space: RGB
# G_ratio:0.8 R_ratio:0.2 B_ratio:0.0
# [Info] Analyze filename... 11_test
# new full images shape:
# (1, 608, 576, 1)
# 240/240 [==============================] - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - 1s 5ms/step
# N_patches_h: 16
# N_patches_w: 15
# N_patches_img: 240
# According to the dimension inserted, there are 1 full images (of 608x576 each)
# 240 240
# using avg
# Color Space: RGB
# G_ratio:0.8 R_ratio:0.2 B_ratio:0.0
# [Info] Analyze filename... 12_test
# new full images shape:
# (1, 608, 576, 1)
# 240/240 [==============================] - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - 1s 5ms/step
# N_patches_h: 16
# N_patches_w: 15
# N_patches_img: 240
# According to the dimension inserted, there are 1 full images (of 608x576 each)
# 240 240
# using avg
# Color Space: RGB
# G_ratio:0.8 R_ratio:0.2 B_ratio:0.0
# [Info] Analyze filename... 13_test
# new full images shape:
# (1, 608, 576, 1)
# 240/240 [==============================] - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - 1s 5ms/step
# N_patches_h: 16
# N_patches_w: 15
# N_patches_img: 240
# According to the dimension inserted, there are 1 full images (of 608x576 each)
# 240 240
# using avg
# Color Space: RGB
# G_ratio:0.8 R_ratio:0.2 B_ratio:0.0
# [Info] Analyze filename... 14_test
# new full images shape:
# (1, 608, 576, 1)
# 240/240 [==============================] - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - 1s 5ms/step
# N_patches_h: 16
# N_patches_w: 15
# N_patches_img: 240
# According to the dimension inserted, there are 1 full images (of 608x576 each)
# 240 240
# using avg
# Color Space: RGB
# G_ratio:0.8 R_ratio:0.2 B_ratio:0.0
# [Info] Analyze filename... 15_test
# new full images shape:
# (1, 608, 576, 1)
# 240/240 [==============================] - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - 1s 5ms/step
# N_patches_h: 16
# N_patches_w: 15
# N_patches_img: 240
# According to the dimension inserted, there are 1 full images (of 608x576 each)
# 240 240
# using avg
# Color Space: RGB
# G_ratio:0.8 R_ratio:0.2 B_ratio:0.0
# [Info] Analyze filename... 16_test
# new full images shape:
# (1, 608, 576, 1)
# 240/240 [==============================] - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - 1s 5ms/step
# N_patches_h: 16
# N_patches_w: 15
# N_patches_img: 240
# According to the dimension inserted, there are 1 full images (of 608x576 each)
# 240 240
# using avg
# Color Space: RGB
# G_ratio:0.8 R_ratio:0.2 B_ratio:0.0
# [Info] Analyze filename... 17_test
# new full images shape:
# (1, 608, 576, 1)
# 240/240 [==============================] - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - 1s 5ms/step
# N_patches_h: 16
# N_patches_w: 15
# N_patches_img: 240
# According to the dimension inserted, there are 1 full images (of 608x576 each)
# 240 240
# using avg
# Color Space: RGB
# G_ratio:0.8 R_ratio:0.2 B_ratio:0.0
# [Info] Analyze filename... 18_test
# new full images shape:
# (1, 608, 576, 1)
# 240/240 [==============================] - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - 1s 5ms/step
# N_patches_h: 16
# N_patches_w: 15
# N_patches_img: 240
# According to the dimension inserted, there are 1 full images (of 608x576 each)
# 240 240
# using avg
# Color Space: RGB
# G_ratio:0.8 R_ratio:0.2 B_ratio:0.0
# [Info] Analyze filename... 19_test
# new full images shape:
# (1, 608, 576, 1)
# 240/240 [==============================] - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - 1s 5ms/step
# N_patches_h: 16
# N_patches_w: 15
# N_patches_img: 240
# According to the dimension inserted, there are 1 full images (of 608x576 each)
# 240 240
# using avg
# Color Space: RGB
# G_ratio:0.8 R_ratio:0.2 B_ratio:0.0
# [Info] Analyze filename... 20_test
# new full images shape:
# (1, 608, 576, 1)
# 240/240 [==============================] - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - 1s 5ms/step
# N_patches_h: 16
# N_patches_w: 15
# N_patches_img: 240
# According to the dimension inserted, there are 1 full images (of 608x576 each)
# 240 240
# using avg
# [INFO] Metric results...
# [INFO] Fininshed...

# %%
def Metric(mask_path,result_path,gt_path,threshold=128):   
    tp = []
    fn = []
    tn = []
    fp = []
    #target_path = './metric/DRIVE/Final_Result/'
    #if not os.path.exists(target_path):
       # os.mkdir(target_path)
#        
#    if not os.path
    for thresh in tqdm(range(129,130)):
        temp_tp = 0
        temp_tn = 0
        temp_fp = 0
        temp_fn = 0
        AUC = 0

        for name in os.listdir(gt_path):
            gt_name = os.path.join(gt_path,name)
            gt =  np.array(Image.open((gt_name)))
            mask_name = name.replace('manual1.tif','test_mask.tif')
#            mask_name = name.replace('manual1.tif','training_mask.tif')

            mask_name = os.path.join(mask_path,mask_name)
#            print(mask_name)
            
            mask = cv2.imread(mask_name,0)
#            print(mask.shape)
            result_name = name.replace('manual1.tif','test_prob.bmp')
#            print(result_name)
#            result_name = name.replace('manual1.tif','training_prob.bmp')

            result_name_path = os.path.join(result_path,result_name.replace('bmp','tif'))
            result = cv2.imread(result_name_path,0)
            

    
            
#            result1 =result
#            result1[result1>=127]=255
#            result1[result1<127]=0
#            cv2.imwrite(target_path+name,result1)            
            
            prob_img = result
            gt_img = gt
#            numpy_name = result_name.replace('test_prob.bmp','test.npy')
#            prob_numpy = np.load(numpy_name)
            FOV_result = []
            FOV_gt = []
#            total_result += result
#            total_gt += gt
            for i in range(mask.shape[0]):
                for j in range(mask.shape[1]):
                    if mask[i][j] > 0 :
                        FOV_result.append(result[i][j])
                        FOV_gt.append(gt[i][j])
            
            prob_img = np.array(FOV_result)
#            prob_img[prob_img>120]=128
            gt_img = (np.array(FOV_gt)>0 )* 1
#            total_result += result
#            total_gt += gt
            AUC+= roc_auc_score(gt_img,prob_img)
#        print(AUC/20)
            new_result = (np.array(prob_img)>thresh)*1
            new_gt = (np.array(gt_img)>0)*1
#        
            temp_tp += np.sum(new_result * new_gt)
            temp_tn += np.sum((1-new_result) * (1-new_gt))
            temp_fn += np.sum((1-new_result) *new_gt)
            temp_fp += np.sum(new_result * (1-new_gt))
#        AUC+= roc_auc_score(total_gt/20,total_result/20)2
        print(AUC/20)            
#        print(AUC)
        tp.append(temp_tp)
        tn.append(temp_tn)
        fp.append(temp_fp)
        fn.append(temp_fn)
##    print(tp)
#    
    tp = np.asarray(tp).astype('float32')    
    tn = np.asarray(tn).astype('float32')
    fp = np.asarray(fp).astype('float32')
    fn = np.asarray(fn).astype('float32')
##    print(tp)
    sen =  tp / (tp+fn)
    spe =  tn / (tn+fp)
    acc = (tp+tn)/(tp+fn+fp+tn)
    threshold = np.argmax(acc)

# 
    print('sen: {} spe: {} acc: {} '.format(sen[threshold],spe[threshold],acc[threshold]))

# %%
config = process_config('./configs/segmention_config.json')
config.color_space = 'RGB'
config.multi_proportion = 1        

config.patch_height = 128
config.G = 0.65
config.R = 0.35
config.B = 0.0 
mask_path = './metric/DRIVE/mask/'
gt_path = './metric/DRIVE/groundtruth/'
if config.color_space == 'RGB':
    config.test_result_path = ".\\experiments\\VesselNet\\dataset\\DRIVE\\validate\\result_demo_RGB\\"
elif config.color_space == 'HSV':
    config.test_result_path = ".\\experiments\\VesselNet\\dataset\\DRIVE\\validate\\result_demo_HSV\\"
elif config.color_space == 'LAB':
    config.test_result_path = ".\\experiments\\VesselNet\\dataset\\DRIVE\\validate\\result_demo_LAB\\"

if config.multi_proportion :
    config.test_result_path = ".\\experiments\\VesselNet\\dataset\\DRIVE\\validate\\result_demo_{}_{}G_{}R_{}B\\".format(config.patch_height,config.G,config.R,config.B)
if not os.path.exists(config.test_result_path):
    os.mkdir(config.test_result_path)
Metric(mask_path,config.test_result_path,gt_path,threshold=0)
# Out:
#   0%|                                                                                            | 0/1 [00:00<?, ?it/s]
# 0.9800723475824837
# 100%|████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:12<00:00, 12.38s/it]
# sen: 0.7950364351272583 spe: 0.9798888564109802 acc: 0.9563594460487366
